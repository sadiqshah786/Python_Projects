# %%
#task 1 Fee VOucher

# %%
std1_info={
    "Name" : "Sadiq Shah",
    "RollNumber" : "AIC00684",
    "Semester" : '2nd',
    "Over All Fee" : 25000
}
std1_name=std1_info["Name"]
std1_RollNumber=std1_info["RollNumber"]
std1_Semester=std1_info["Semester"]
std1_OverAllFee=std1_info["Over All Fee"]

#Student 2
std2_info={
    "Name" : "Seema Noor",
    "RollNumber" : "AIC00564",
    "Semester" : '2nd',
    "Over All Fee" : 25800
}
std2_name=std2_info["Name"]
std2_RollNumber=std2_info["RollNumber"]
std2_Semester=std2_info["Semester"]
std2_OverAllFee=std2_info["Over All Fee"]

#student 3:
std3_info={
    "Name" : "Imtiaz Ali",
    "RollNumber" : "CCN00684",
    "Semester" : '4th',
    "Over All Fee" : 30000
}
std3_name=std3_info["Name"]
std3_RollNumber=std3_info["RollNumber"]
std3_Semester=std3_info["Semester"]
std3_OverAllFee=std3_info["Over All Fee"]

#Fee Voucher...
print("|===================== Student Number 1 ==========================|")
print("|==================== PIAIC FEE VOUCHER ==========================|")
print("|********************    Bank Copy      **************************|")
print('|=================================================================|\n')
print(f"Name : {std1_name}\nStudent ROll Number :  {std1_RollNumber}\nStudent Semester : {std1_Semester}\nFee Semester + Activites : {std1_OverAllFee}")
print("\n")

print("|==================== PIAIC FEE VOUCHER ==========================|")
print("|******************** University COpy   **************************|")
print('|=================================================================|\n')
print(f"Name : {std1_name}\nStudent ROll Number :  {std1_RollNumber}\nStudent Semester : {std1_Semester}\nFee Semester + Activites : {std1_OverAllFee}")
print("\n")

print("|==================== PIAIC FEE VOUCHER ==========================|")
print("|********************   Student COpy    **************************|")
print('|=================================================================|\n')
print(f"Name : {std1_name}\nStudent ROll Number :  {std1_RollNumber}\nStudent Semester : {std1_Semester}\nFee Semester + Activites : {std1_OverAllFee}")

# ***************************************************************************************3************
print("\n")

print("|===================== Student Number 2 ==========================|")
print("|==================== PIAIC FEE VOUCHER ==========================|")
print("|********************    Bank Copy      **************************|")
print('|=================================================================|\n')
print(f"Name : {std3_name}\nStudent ROll Number :  {std3_RollNumber}\nStudent Semester : {std3_Semester}\nFee Semester + Activites : {std3_OverAllFee}")
print("\n")

print("|==================== PIAIC FEE VOUCHER ==========================|")
print("|********************   University Copy **************************|")
print('|=================================================================|\n')
print(f"Name : {std2_name}\nStudent ROll Number :  {std3_RollNumber}\nStudent Semester : {std3_Semester}\nFee Semester + Activites : {std3_OverAllFee}")
print("\n")

print("|==================== PIAIC FEE VOUCHER ==========================|")
print("|********************   Student COpy    **************************|")
print('|=================================================================\n')
print(f"Name : {std2_name}\nStudent ROll Number :  {std3_RollNumber}\nStudent Semester : {std3_Semester}\nFee Semester + Activites : {std3_OverAllFee}")

print("\n")
# *********************************************************************************

print("|===================== Student Number 3 ==========================|")
print("|==================== PIAIC FEE VOUCHER ==========================|")
print("|********************   Bank Copy       ***************************")
print('|==================================================================\n')
print(f"Name : {std3_name}\nStudent ROll Number :  {std2_RollNumber}\nStudent Semester : {std2_Semester}\nFee Semester + Activites : {std2_OverAllFee}")
print("\n")

print("|==================== PIAIC FEE VOUCHER ==========================|")
print("|********************   University COpy **************************|")
print('|=================================================================|\n')
print(f"Name : {std3_name}\nStudent ROll Number :  {std2_RollNumber}\nStudent Semester : {std2_Semester}\nFee Semester + Activites : {std2_OverAllFee}")
print("\n")

print("|==================== PIAIC FEE VOUCHER ==========================|")
print("|********************   Student COpy    **************************|")
print('|=================================================================|\n')
print(f"Name : {std3_name}\nStudent ROll Number :  {std2_RollNumber}\nStudent Semester : {std2_Semester}\nFee Semester + Activites : {std1_OverAllFee}")
# Out:
# |===================== Student Number 1 ==========================|
# |==================== PIAIC FEE VOUCHER ==========================|
# |********************    Bank Copy      **************************|
# |=================================================================|
#
# Name : Sadiq Shah
# Student ROll Number :  AIC00684
# Student Semester : 2nd
# Fee Semester + Activites : 25000
#
#
# |==================== PIAIC FEE VOUCHER ==========================|
# |******************** University COpy   **************************|
# |=================================================================|
#
# Name : Sadiq Shah
# Student ROll Number :  AIC00684
# Student Semester : 2nd
# Fee Semester + Activites : 25000
#
#
# |==================== PIAIC FEE VOUCHER ==========================|
# |********************   Student COpy    **************************|
# |=================================================================|
#
# Name : Sadiq Shah
# Student ROll Number :  AIC00684
# ...

# %%
#Task 2

# %% [markdown]
# # SHELL PRICES + Monthly Shedule

# %%
print("SHELL Petrol Pump Price")
print("========================")
print("\t Petrol")
print("========================")
litre_petrol=114.24
monthly_petrol_S=114.24*500
print(f"Litre Petrol is : {litre_petrol}\nMonthly 500 litre : {monthly_petrol_S}")

print("\n")
print("========================")
print("   Action +  Diesel")
print("=========================")
Diesel=127.41
monthly_Dieseld_S=Diesel*300
print(f"High speed Diesel litre is : {Diesel}\nMonthly 300 litre : {monthly_Dieseld_S}\n")




print("========================")
print(" E10 Kerosense Oil")
print("=========================")
Kerosense_Oil=111.74
monthly_Kerosense_Oil_S=Kerosense_Oil*200
print(f" E10 Keronse oil per litre is : {Kerosense_Oil}\nMonthly 300 litre : {monthly_Kerosense_Oil_S}\n")

print("\n")
# Out:
# SHELL Petrol Pump Price
# ...
# 	 Petrol
# ...
# Litre Petrol is : 114.24
# Monthly 500 litre : 57120.0
#
#
# ...
#    Action +  Diesel
# ...
# High speed Diesel litre is : 127.41
# Monthly 300 litre : 38223.0
#
# ...
#  E10 Kerosense Oil
# ...
#  E10 Keronse oil per litre is : 111.74
# Monthly 300 litre : 22348.0

# %% [markdown]
# # PSO Prices + Monthly Shedule

# %%
print("PSO Petrol Pump Price")
print("========================")
print("\t Petrol")
print("========================")
litre_petrol=114.24
monthly_petrol_O=114.24*500
print(f"Litre Petrol is : {litre_petrol}\nMonthly 500 litre : {monthly_petrol_O}")

print("\n")
print("========================")
print("   High Speed Diesel")
print("=========================")
high_speed_Diesel=127.41
monthly_high_speed=high_speed_Diesel*300
print(f"High speed Diesel litre is : {high_speed_Diesel}\nMonthly 300 litre : {monthly_high_speed}\n")

print("=========================")
print("   Light Speed Diesel")
print("=========================")
low_speed_Diesel=85.33
monthly_low_speed=low_speed_Diesel*300
print(f"High speed Diesel litre is : {low_speed_Diesel}\nMonthly 300 litre : {monthly_low_speed}\n")



print("========================")
print("Kerosense Oil")
print("=========================")
Kerosense_Oil=97.18
monthly_Kerosense_Oil_O=Kerosense_Oil*200
print(f"High speed Diesel litre is : {Kerosense_Oil}\nMonthly 300 litre : {monthly_Kerosense_Oil_O}\n")
# Out:
# PSO Petrol Pump Price
# ...
# 	 Petrol
# ...
# Litre Petrol is : 114.24
# Monthly 500 litre : 57120.0
#
#
# ...
#    High Speed Diesel
# ...
# High speed Diesel litre is : 127.41
# Monthly 300 litre : 38223.0
#
# ...
#    Light Speed Diesel
# ...
# High speed Diesel litre is : 85.33
# Monthly 300 litre : 25599.0
#
# ...
# Kerosense Oil
# ...
# High speed Diesel litre is : 97.18
# Monthly 300 litre : 19436.0

# %% [markdown]
# # Compare PSO prices and Shell Prices

# %%
print("Compare shell VS PSO")
print("=====================\n")
print("PSO prices monthly Plane")
print("========================")
print(f"Monthly Petrol : {monthly_petrol_O}\nMonthly Diesel Low :{monthly_low_speed},Monthly Diesel High :{monthly_high_speed}\nMonthly Keronse oil : {monthly_Kerosense_Oil_O}")

print("\n")

print("SHELL prices monthly Plane")
print("===========================")
print(f"Monthly Petrol : {monthly_petrol_S}\nMonthly Diesel :{monthly_Dieseld_S}\nMonthly Keronse oil : {monthly_Kerosense_Oil_S}")
# Out:
# Compare shell VS PSO
# ...
#
# PSO prices monthly Plane
# ...
# Monthly Petrol : 57120.0
# Monthly Diesel Low :25599.0,Monthly Diesel High :38223.0
# Monthly Keronse oil : 19436.0
#
#
# SHELL prices monthly Plane
# ...
# Monthly Petrol : 57120.0
# Monthly Diesel :38223.0
# Monthly Keronse oil : 22348.0
