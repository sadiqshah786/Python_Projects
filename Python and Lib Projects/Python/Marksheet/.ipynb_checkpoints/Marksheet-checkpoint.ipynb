# %% [markdown]
# # MarkSheet

# %%
print("\t\t---------------------------------------------------------")
print("\t\t\t\t\tMarks Sheet")
print("\t\t---------------------------------------------------------")
name=input("Enter Your Name : ")
F_name=input("Enter Your Father Name : ")
Roll_no=int(input("Enter Your Roll No : "))
Class=int(input("Which class are You Studying\n"))


if Class in [1,2,3,4,5,6,7,8]:
    urdu=int(input("Enter your marks of Urdu : "))
    Eng=int(input("Enter your  marks of English : "))
    Isl=int(input("Enter your  marks of Islamiat : "))
    Math=int(input("Enter your marks of Maths  : "))
    Sci= int(input("Enter your marks of Science : "))
    Comp=int(input("Enter your marks of Computer : "))
    SST=int(input("Enter your  marks of SST : "))
    print("\n")
    
    obt_marks=urdu+Eng+Isl+Math+Sci+Comp+SST
    print(f"Your Obtained Marks : {obt_marks}\n")
    
    total_marks=700
    
    percent=(obt_marks/total_marks)*100
    per=(round(percent, 2))
    print(f"Your Percentage : {per}")
    
    
    #grade
    if per>=90:
        print("A+ Grade")
    elif per>=80 and per<=89:
        print("A-1 Grade")
    elif per>=70 and per<=79:
        print("A Grade")
    elif per>=60 and per<=69:
        print("B Grade")
    elif per>=50 and per<=59:
        print("C Grade")
    elif per>=40 and per<=49:
        print("D Grade")
    elif per<=40:
        print("Fail")
        
    
    
    
elif Class==9:
    Eng=int(input("Enter your  marks of English out of '100' : "))
    PST=int(input("Enter your  marks of PST out of '75' : "))
    Bio=int(input("Enter your marks of Biology out of '100' : "))
    Chem= int(input("Enter your marks of Chemistry out of '100': "))
    Comp=int(input("Enter your marks of Computerout of '75' : "))
    
    obt_marks=Eng+PST+Bio+Chem+Comp
    print(f"Your Obtained Marks : {obt_marks}\n")
    
    total_marks=425
    
    percent=(obt_marks/total_marks)*100
    per=(round(percent, 2))
    print(f"Your Percentage : {per}")
    
    
    if per>=90:
        print("A+ Grade")
    elif per>=80 and per<=89:
        print("A-1 Grade")
    elif per>=70 and per<=79:
        print("A Grade")
    elif per>=60 and per<=69:
        print("B Grade")
    elif per>=50 and per<=59:
        print("C Grade")
    elif per>=40 and per<=49:
        print("D Grade")
    elif per<=40: 
        print("Fail")
    
    
    
    
    
elif Class==10:
    print("\n")
    print("Enter YOur marks of Class 9th")
    
    Eng1=int(input("Enter your  marks of English out of '100' : "))
    PST=int(input("Enter your  marks of PST out of '75' : "))
    Bio=int(input("Enter your marks of Biology out of '100' : "))
    Chem= int(input("Enter your marks of Chemistry out of '100': "))
    Comp=int(input("Enter your marks of Computer out of '75' : "))
    
    print("\n")
    urdu=int(input("Enter your marks of Urdu  out of '75': "))
    Eng2=int(input("Enter your  marks of English out of '100' : "))
    Isl=int(input("Enter your  marks of Islamiat out of '75' : "))
    Math=int(input("Enter your marks of Maths  out of '100' : "))
    Physic= int(input("Enter your marks of Physics out of '100' : "))
    
    obt_marks=Eng1+PST+Bio+Chem+Comp+Eng2+urdu+Isl+Math+Physic
    print(f"Your Obtained Marks : {obt_marks}\n")
    
    total_marks=850
    
    percent=(obt_marks/total_marks)*100
    per=(round(percent, 2))
    print(f"Your Percentage : {per}")
    
    if per>=90:
        print("A+ Grade")
    elif per>=80 and per<=89:
        print("A-1 Grade")
    elif per>=70 and per<=79:
        print("A Grade")
    elif per>=60 and per<=69:
        print("B Grade")
    elif per>=50 and per<=59:
        print("C Grade")
    elif per>=40 and per<=49:
        print("D Grade")
    elif per<=40:
        print("Fail")
    
else:
    print("Invalid Class !")
# Out:
# 		---------------------------------------------------------
# 					Marks Sheet
# 		---------------------------------------------------------
# Enter Your Name : sadiq shah
# Enter Your Father Name : naseeb shah
# Enter Your Roll No : 456
# Which class are You Studying
# 3
# Enter your marks of Urdu : 45
# Enter your  marks of English : 67
# Enter your  marks of Islamiat : 65
# Enter your marks of Maths  : 77
# Enter your marks of Science : 67
# Enter your marks of Computer : 56
# Enter your  marks of SST : 78
#
#
# Your Obtained Marks : 455
#
# Your Percentage : 94.71
# A+ Grade

# %% [markdown]
# ######
