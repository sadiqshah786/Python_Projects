# %%
import getpass
class HMS():   
    def __init__(self,hospital_name,adress):                     
        self.hospital_name=hospital_name                      #Hospital introduction
        self.adress=adress
        print(" |=======================================|")
        print(" | Welcome to Hospital Management System |")
        print(" |=======================================|")
        print(f"hospital name is:'{self.hospital_name}'\nAdress is located:'{self.adress}' \n")
        
        
        
        
    def hosp_service(self):
            user_input=input("Do you want to know about the services of Hospital : ").title()
            if user_input=='Yes': 
                print("Thanks,But Firstly You should create an account")
                hosp.reg_login()
                hosp.hospital_info()
                                                        
            else:
                print("Sorry,We can't give you any information")
                
                             #End function
        
        
        
                            #................Reg and login function........
    def reg_login(self):
        
        #Registration......
        
        print("Create an Account")
        f_name=input("First Name : ")
        l_name=input("Last Name : ")
        password=getpass.getpass("Password : ")
        c_pass=getpass.getpass("Confirm Password :")
        
        if password==c_pass:
            Email=input("Email: ")
            if '@' in Email:                        #Email validation
                gender=input("Gender: Male OR Female: ")
                print(gender)
                 
                print("Date of Birth")    
                date=int(input("Date : "))
                day=int(input("Month : "))
                year=int(input("Year : "))
                print(f' Date of Birth : {date}/{day}/{year}')
                        
                        
                contact=int(input("Contact No: "))
                
            else:
                e=True
                while e:
                    Email=input("Something is missing e.g '@,Again Enter Email: ")
                    if '@' in Email:
                        
                        gender=input("Gender: Male OR Female: ")
                        print(gender)
                        
                        
                        
                        date=int(input("Date : "))
                        day=int(input("Month : "))
                        year=int(input("Year : "))
                        print(f' Date of Birth: {date}/{day}/{year}')
                        
                        
                        contact=int(input("Contact No: "))
                        
                        e=False
                    
                        
            print(f"Email : {Email}\nPassword : {c_pass}")
            print("You have been registered Succssfull,now you can sucsessfully login")
            
            
            #.............................Registration form end...........................................
                              
            print('\t\t~~~~~~~~~~~~~~~~~~~~~~~')                  
            print("\t\t| LOGIN   FORM  | ")
            print('\t\t~~~~~~~~~~~~~~~~~~~~~~~')
            
           
            user_input=input("Do you want to login your account ?").title()
            if user_input=="Yes":
                user_email=input("Email: ")
                if user_email==Email:
                    user_password=getpass.getpass("Password")
                    if user_password==c_pass:
                                 print("Login Succsessfully")   
                else:
                    a=True
                    while a:
                        user_email=input(" Incorrect ! Re-Enter Email ")
                        if user_email==Email:
                            user_password=getpass.getpass("Password")
                            a=False
                            if user_password==c_pass:
                                 print("Login Succsessfully")
                            else:
                                 s=True
                                 while s:
                                     user_password=getpass.getpass("Incorrect ! Re-Enter Password")
                                     if user_password==c_pass:
                                         print("Login Succsessfully")
                                         s=False
                                         
            else:
                print("Thanks you For Create an account\nYou can Visit Another time\nThanks")
                       
        else:
            FLAG=True
            while FLAG:
                c_pass=getpass.getpass("No Match,Re-Enter Password : ")
                if password==c_pass:
                    Email=input("Email: ")
                    if '@' in Email:
                        gender=input("Gender: Male OR Female: ")
                        print(gender)
                        
                        
                        
                        date=int(input("Date : "))
                        day=int(input("Month : "))
                        year=int(input("Year : "))
                        print(f'Date of Birt: {date}/{day}/{year}')
                        
                        
                        contact=int(input("Contact No: "))
                        FLAG= False

            
            print(f"Email : {Email}\nPassword : {c_pass}")
            print("You have been registered Succssfull,now you can sucsessfully login")
                              
            print('\t\t~~~~~~~~~~~~~~~~~~~~~~~')                  
            print("\t\t| LOGIN   FORM  | ")
            print('\t\t~~~~~~~~~~~~~~~~~~~~~~~')
            
           
            user_input=input("Do you want to login your account ?").title()
            if user_input=="Yes":
                user_email=input("Email: ")
                if user_email==Email:
                    user_password=getpass.getpass("Password")
                    if user_password==c_pass:
                                 print("Login Succsessfully")   
                else:
                    a=True
                    while a:
                        user_email=input(" Incorrect ! Re-Enter Email ")
                        if user_email==Email:
                            user_password=getpass.getpass("Password")
                            a=False
                            if user_password==c_pass:
                                 print("Login Succsessfully")
                            else:
                                 s=True
                                 while s:
                                     user_password=getpass.getpass("Incorrect ! Re-Enter Password")
                                     if user_password==c_pass:
                                         print("Login Succsessfully")
                                         s=False
                                         
                                         
            else:
                print("Thanks you For Create an account\nYou can Visit Another time\nThanks")
                
#...................................... End reg and login from.............................................................
                                     
                
#........................................ Hospital info  ..................................................................               
    def hospital_info(self):
        print('=========================================================================================================')
        print("\t\t\t\t\tInformation About Hospital")
        print('=========================================================================================================')
        print("\t\t\t\t\t  Doctors  informations")   
        print('=========================================================================================================')
        drs={
            
            'Dr.Qammar' : 'Bones',
            'Dr.Hammed' : 'Skin',
            'Dr.Kamraan' : 'Teeth',
            'Dr.Faizan' : 'Burning Effects',
            'Dr.Ajmal' : 'Fever(typied)',
            'Dr.Rafeeq' : 'Cancer',
            'Dr.Kashif' : 'TB',
            'Dr.Nasir Uddin' : 'Through infection'
        }
        for i,j in drs.items():
            print("-",i,"Especialist in",j) 
            
            
        print('=========================================================================================================')
        print("\t\t\t\t\t  Hospital Ward  informations")   
        print('=========================================================================================================')
        wards={
            "Anesthetics : \n"  :  "An anesthetic is a drug or agent that produces a complete or partial loss of feeling\n",
            
            "Breast Screening : \n": "Screens women for breast cancer and is usually linked to the X-ray or radiology department\n",
            
            "Burn Center(Burn Unit or Burns Unit) : \n" :"A hospital specializing in the treatment of burns\n  Burn centers are often used for the treatment and recovery of patients with more severe burns\n",
            
            "Cardiology : \n  " : "Provides medical care to patients who have problems with their heart or circulation\n",
            
            "Diagnostic Imaging : \n  ": "Also known as X-Ray Department and/or Radiology Department\n",
      
            "General Services : \n  ": "Support Services include services provided by Department\n",
            
            "General Surgery : \n": "Covers a wide range of types of surgery and procedures on patients\n",
     
            "Maternity : \n": "Maternity wards provide antenatal care, delivery of babies and care during childbirth, and postnatal support\n",
            
            "Radiotherapy : \n": "Also called radiation therapy, is the treatment of cancer and other diseases with ionizing radiation\n",
     
            "Sexual Health : \n" : "Also known as genitourinary medicine Provides advice, testing and treatment for sexually transmitted infections,\n Family planning care, pregnancy testing and advice, care and support for sexual and genital problems"     
            
        }
        for name,info in wards.items():
            print("-" , name,info)
    
    
        print('=========================================================================================================')
        print("\t\t\t\t\t  No of beds in Hospitals")   
        print('=========================================================================================================')
        print(' - There are 200 no of beds')

#.....................................................Funtion End...........................................................
        
        hosp.dr_info()   #calling Dr object

#      ....................................................  dr info ............................................
            
    def dr_info(self):
            print("===============")
            print("List of Doctors")
            print("===============")
            drs={
                'Dr.Qammar' : ' : Bones',
                'Dr.Hammed' : ' : Skin',
                'Dr.Kamraan' : ': Teeth',
                'Dr.Faizan' : ' : Burning Effects',
                'Dr.Ajmal' : '  : Fever(typied)',
                'Dr.Rafeeq' : ' : Cancer',
                'Dr.Kashif' : ' : TB',
                'Dr.Nasir Uddin' : ': Through infection'
                }
        
            for i,j in drs.items():
                print(i,j)
            hosp.reception()   #calling object  reception
        
        
        #.............................................End function............................................
                
    
    #......................................Reception.................................................................
    
    def reception(self):
        user_sug=input("DO you want to take appointement?? ").title()
        if user_sug=='Yes':
            disease =input("Your  disease ??? : -\n")
            drs={
                'Dr.Qammar' : ' : Bones',
                'Dr.Hammed' : ' : Skin',
                'Dr.Kamraan' : ': Dentist',
                'Dr.Faizan' : ' : Burning Effects',
                'Dr.Ajmal' : '  : Fever(Typhoid)',
                'Dr.Rafeeq' : ' : Cancer',
                'Dr.Kashif' : ' : TB',
                'Dr.Nasir Uddin' : ': Through infection'
                }
            for  i,j in drs.items():
                if disease in j:
                    print(f"You should Consult with {i} Because {i} is best in {disease} treatment\n")
                    a=input(f"Do want to fixed appoinment with  {i} : \n").title()  
                    if a=="Yes":
                        print("Avalible Date")  
                        print("=============")
                        dates=[2,4,5,11,12,16,18,19]
                        for j in dates:
                            print(j , 'Sep,' , "Oct,", "Nov,","Dec")
                            print("\n")         
                    
                            days=["Monday  :  9:00 AM TO 12:00 PM\n","Wednesday :  4:00 AM TO 6:00  AM\n","Thursday  : 9:00 PM T0 10:00 AM\n"]
                            print("Avalible Days & Timing") 
                            print('=====================')
                            for k in days:
                                print(k)
                            
            user_month=input("Appoiment Month : ")   
            user_date=int(input("Appoinment Date  : "))
            user_day =input("Appoinment Day : ")
            print("\n")
            
            
            print("Your Appoinment has been at Scheduled")
            print("=============================")
            print("\n")
            print(f' Set Appoinment:{user_month} : {user_date} / {user_day} / 2019')
    

                
               
                        
        else:
            print("After Login you can Fixed Appointment")  #ab kro run
            
            
            
#...............................................End Reception....................................................................

# %%
hosp=HMS("Jinnah",'Cant station')  # program filhal no..of monmth dalo>>>>>>> acha bhai
hosp.hosp_service()
# Out:
#  |=======================================|
#  | Welcome to Hospital Management System |
#  |=======================================|
# hospital name is:'Jinnah'
# Adress is located:'Cant station'
#
# Do you want to know about the services of Hospital : yes
# Thanks,But Firstly You should create an account
# Create an Account
# First Name : sadiq
# Last Name : shah
# Password : ········
# Confirm Password :········
# Email: @
# Gender: Male OR Female: Male
# Male
# Date of Birth
# Date : 5
# Month : 10
# Year : 1998
#  Date of Birth : 5/10/1998
# Contact No: 03218799686
# Email : @
# Password : 123
# You have been registered Succssfull,now you can sucsessfully login
# 		~~~~~~~~~~~~~~~~~~~~~~~
# 		| LOGIN   FORM  |
# 		~~~~~~~~~~~~~~~~~~~~~~~
# Do you want to login your account ?yes
# Email: @
# Password········
# Login Succsessfully
# ...
# 					Information About Hospital
# ...
# 					  Doctors  informations
# ...
# - Dr.Qammar Especialist in Bones
# - Dr.Hammed Especialist in Skin
# ...

# %%
 wards={
            "Anesthetics : \n"  :  "An anesthetic is a drug or agent that produces a complete or partial loss of feeling\n",
            
            "Breast Screening : \n": "Screens women for breast cancer and is usually linked to the X-ray or radiology department\n",
            
            "Burn Center(Burn Unit or Burns Unit) : \n" :"A hospital specializing in the treatment of burns\n  Burn centers are often used for the treatment and recovery of patients with more severe burns\n",
            
            "Cardiology : \n  " : "Provides medical care to patients who have problems with their heart or circulation\n",
            
            "Diagnostic Imaging : \n  ": "Also known as X-Ray Department and/or Radiology Department\n",
      
            "General Services : \n  ": "Support Services include services provided by Department\n",
            
            "General Surgery : \n": "Covers a wide range of types of surgery and procedures on patients\n",
     
            "Maternity : \n": "Maternity wards provide antenatal care, delivery of babies and care during childbirth, and postnatal support\n",
            
            "Radiotherapy : \n": "Also called radiation therapy, is the treatment of cancer and other diseases with ionizing radiation\n",
     
            "Sexual Health : \n" : "Also known as genitourinary medicine Provides advice, testing and treatment for sexually transmitted infections,\n Family planning care, pregnancy testing and advice, care and support for sexual and genital problems"     
            
        }
for name,info in wards.items():
    print("-" , name,info)
# Out:
# - Anesthetics :
#  An anesthetic is a drug or agent that produces a complete or partial loss of feeling
#
# - Breast Screening :
#  Screens women for breast cancer and is usually linked to the X-ray or radiology department
#
# - Burn Center(Burn Unit or Burns Unit) :
#  A hospital specializing in the treatment of burns
#   Burn centers are often used for the treatment and recovery of patients with more severe burns
#
# - Cardiology :
#    Provides medical care to patients who have problems with their heart or circulation
#
# - Diagnostic Imaging :
#    Also known as X-Ray Department and/or Radiology Department
#
# - General Services :
#    Support Services include services provided by Department
#
# - General Surgery :
#  Covers a wide range of types of surgery and procedures on patients
#
# - Maternity :
#  Maternity wards provide antenatal care, delivery of babies and care during childbirth, and postnatal support
#
# - Radiotherapy :
# ...
