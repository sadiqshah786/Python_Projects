# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from matplotlib  import  style

# %%
data=pd.read_csv('D:\\PIAIC DOC\\Q2\\pandas\\DataSet\\suicide-rates-overview-1985-to-2016\\master.csv')

# %%
data
# Out:
#           country  year     sex          age  suicides_no  population  \
# 0         Albania  1987    male  15-24 years           21      312900
# 1         Albania  1987    male  35-54 years           16      308000
# 2         Albania  1987  female  15-24 years           14      289700
# 3         Albania  1987    male    75+ years            1       21800
# 4         Albania  1987    male  25-34 years            9      274300
# 5         Albania  1987  female    75+ years            1       35600
# 6         Albania  1987  female  35-54 years            6      278800
# 7         Albania  1987  female  25-34 years            4      257200
# 8         Albania  1987    male  55-74 years            1      137500
# 9         Albania  1987  female   5-14 years            0      311000
# 10        Albania  1987  female  55-74 years            0      144600
# 11        Albania  1987    male   5-14 years            0      338200
# ...

# %%
data.dropna(axis=1,inplace=True)
data
# Out:
#           country  year     sex          age  suicides_no  population  \
# 0         Albania  1987    male  15-24 years           21      312900
# 1         Albania  1987    male  35-54 years           16      308000
# 2         Albania  1987  female  15-24 years           14      289700
# 3         Albania  1987    male    75+ years            1       21800
# 4         Albania  1987    male  25-34 years            9      274300
# 5         Albania  1987  female    75+ years            1       35600
# 6         Albania  1987  female  35-54 years            6      278800
# 7         Albania  1987  female  25-34 years            4      257200
# 8         Albania  1987    male  55-74 years            1      137500
# 9         Albania  1987  female   5-14 years            0      311000
# 10        Albania  1987  female  55-74 years            0      144600
# 11        Albania  1987    male   5-14 years            0      338200
# ...

# %%
infom=data[(data.country=="Albania") & (data.sex=="male")]
infom=data[(data.country=="Argentina") & (data.sex=="male") & (data.age=="15-24 years")]
infom=data[(data.country=="Argentina") & (data.sex=="male") & (data.age=="25-34 years")]
infom=data[(data.country=="Argentina") & (data.sex=="male") & (data.age=="35-54 years")]
infom=data[(data.country=="Argentina") & (data.sex=="male") & (data.age=="55-74 years")]
infom=data[(data.country=="Argentina") & (data.sex=="male") & (data.age=="75+ years")]

# %%
infom2.age.value_counts(normalize=True).mul(100).round(1).astype(str) + '%'
# Out:
# 15-24 years    100.0%
# Name: age, dtype: object

# %%
infom3.age.value_counts(normalize=True).mul(100).round(1).astype(str) + '%'
# Out:
# 25-34 years    100.0%
# Name: age, dtype: object
