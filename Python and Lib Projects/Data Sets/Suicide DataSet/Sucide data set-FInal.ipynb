# %% [markdown]
# # Sucide Data Set

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from matplotlib  import  style

# %%
data=pd.read_csv('D:\\PIAIC DOC\\Q2\\pandas\\DataSet\\suicide-rates-overview-1985-to-2016\\master.csv')

# %%
data
# Out:
#           country  year     sex          age  suicides_no  population  \
# 0         Albania  1987    male  15-24 years           21      312900
# 1         Albania  1987    male  35-54 years           16      308000
# 2         Albania  1987  female  15-24 years           14      289700
# 3         Albania  1987    male    75+ years            1       21800
# 4         Albania  1987    male  25-34 years            9      274300
# 5         Albania  1987  female    75+ years            1       35600
# 6         Albania  1987  female  35-54 years            6      278800
# 7         Albania  1987  female  25-34 years            4      257200
# 8         Albania  1987    male  55-74 years            1      137500
# 9         Albania  1987  female   5-14 years            0      311000
# 10        Albania  1987  female  55-74 years            0      144600
# 11        Albania  1987    male   5-14 years            0      338200
# ...

# %% [markdown]
# # Rows and Columns

# %%
data.shape
print(f"Rows :",data.shape[0])
print(f"Columns :",data.shape[1])
# Out:
# Rows : 27820
# Columns : 12

# %% [markdown]
# # Checking the NAN values

# %%
data.isnull().sum()
# Out:
# country                  0
# year                     0
# sex                      0
# age                      0
# suicides_no              0
# population               0
# suicides/100k pop        0
# country-year             0
# HDI for year         19456
#  gpy                     0
# gdp_per_capita           0
# generation               0
# dtype: int64

# %% [markdown]
# # Clean Data

# %%
data.dropna(axis=1,inplace=True)
# data

# %% [markdown]
# # Identifies of columns

# %%
columns= data.columns
# columns
print("------------------------")
print("Columns of The data Set")
print("------------------------")
for i in columns:
    print("-" , i)
# Out:
# ------------------------
# Columns of The data Set
# ------------------------
# - country
# - year
# - sex
# - age
# - suicides_no
# - population
# - suicides/100k pop
# - country-year
# - HDI for year
# -  gpy
# - gdp_per_capita
# - generation

# %% [markdown]
# # Name of Attempted Suicides Coutries

# %%
countries=data.country.unique()
print("-----------------------------------")
print("Name of Attempted Suicides Coutries")
print("-----------------------------------")

for i in countries:
    print("-",i,end="|")
# Out:
# -----------------------------------
# Name of Attempted Suicides Coutries
# -----------------------------------
# ...

# %% [markdown]
# # Suicides ages M & F

# %%
age=data.age.unique()
print("------------------------------")
print("Suicides Years Male and female")
print("------------------------------")
for i in age:
    print("-",i)
# Out:
# ------------------------------
# Suicides Years Male and female
# ------------------------------
# - 15-24 years
# - 35-54 years
# - 75+ years
# - 25-34 years
# - 55-74 years
# - 5-14 years

# %% [markdown]
# # Total no of suicides attempted in countries

# %%
print("---------------------------------")
print("Total no of suicides in countries")
print("---------------------------------")
suicides_no=data.suicides_no.sum()
print("Total Suicides : " , suicides_no)
# Out:
# ---------------------------------
# Total no of suicides in countries
# ---------------------------------
# Total Suicides :  6748420

# %% [markdown]
# # Updates years of Suicides

# %%
years=data.year.unique()
for i in years:
    print(i, end=" |")
# Out:
# 1987 |1988 |1989 |1992 |1993 |1994 |1995 |1996 |1997 |1998 |1999 |2000 |2001 |2002 |2003 |2004 |2005 |2006 |2007 |2008 |2009 |2010 |1985 |1986 |1990 |1991 |2012 |2013 |2014 |2015 |2011 |2016 |

# %% [markdown]
# # describe All statistics Values

# %%
data.describe()
# Out:
#                year   suicides_no    population  suicides/100k pop  \
# count  27820.000000  27820.000000  2.782000e+04       27820.000000
# mean    2001.258375    242.574407  1.844794e+06          12.816097
# std        8.469055    902.047917  3.911779e+06          18.961511
# min     1985.000000      0.000000  2.780000e+02           0.000000
# 25%     1995.000000      3.000000  9.749850e+04           0.920000
# 50%     2002.000000     25.000000  4.301500e+05           5.990000
# 75%     2008.000000    131.000000  1.486143e+06          16.620000
# max     2016.000000  22338.000000  4.380521e+07         224.970000
#
#        gdp_per_capita
# count     27820.000000
# mean      16866.464414
# std       18887.576472
# min         251.000000
# 25%        3447.000000
# 50%        9372.000000
# 75%       24874.000000
# max      126352.000000

# %% [markdown]
# # Information About Dataset

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 27820 entries, 0 to 27819
# Data columns (total 11 columns):
# country              27820 non-null object
# year                 27820 non-null int64
# sex                  27820 non-null object
# age                  27820 non-null object
# suicides_no          27820 non-null int64
# population           27820 non-null int64
# suicides/100k pop    27820 non-null float64
# country-year         27820 non-null object
#  gpy                 27820 non-null object
# gdp_per_capita       27820 non-null int64
# generation           27820 non-null object
# dtypes: float64(1), int64(4), object(6)
# memory usage: 1.7+ MB

# %% [markdown]
#    ------------------------
#                                                    Insight Reports
#    -------------------------
#
#    * Total Number of suicide in total countries (1987-2016)
#    * Who got suicides more (Teen,Adult,Elder)
#    * Number of suicide each year of 5 famous countries (1987-2016)
# - According to
#        - Male
#        - Female
# * According to age number of suicides of 5 famous countries
#
# * Growth product development of each countries from 1987-2016
#
# * Ration of suicides in each countries along years 1987-2016

# %% [markdown]
# # Sucide attempt 1987 to 2016
#  - visualize by Graph

# %%
year=data.year
sucicedes=data.suicides_no
plt.figure(figsize=(12,5))
plt.scatter(year,sucicedes,label="Suicides Attemps",color='m') 
plt.xlabel("Suicided Years")
plt.ylabel("Number of Attempted Suicides")
style.use('ggplot')
plt.legend()
plt.title("Suicides Attempt from 1987 to 2016 ")
# Out:
# Text(0.5, 1.0, 'Suicides Attempt from 1987 to 2016 ')

# %% [markdown]
# # Overall Countries Who tend to commit suicide more? Teens? Adults? elders?

# %%
Sui_ages=data.age
sucicedes=data.suicides_no
plt.figure(figsize=(12,5))
plt.bar(Sui_ages,sucicedes,label="Suicides Attemps",color='cornflowerblue') 
plt.xlabel("Suicided Years")
plt.ylabel("Number of Attempted Suicides")
style.use('ggplot')
plt.legend()
plt.title("Suicides Attempt from 1987 to 2016 ")

# %% [markdown]
# # Overall Number of Suicide male and female

# %%
plt.figure(figsize=(12,5))
sex=data.groupby(["sex"]).get_group('male')
male=sex.suicides_no.sum()
sex=data.groupby(["sex"]).get_group('female')
female=sex.suicides_no.sum()
plt.bar(["male",'female'],[male,female])
# Out:
# <BarContainer object of 2 artists>

# %% [markdown]
# # 5-Selected Country

# %% [markdown]
# # Country,Year,ages
# - Albania
# - 1987-2016
# - ages
#    - 15-24 years
#    - 35-54 years
#    - 75+ years
#    - 25-34 years
#    - 55-74 years
#    - 5-14 years
# - Male & Female

# %%
info=data[(data.country=="Albania") & (data.year==1987) & (data.sex=="male")]
s_n_m1=info.suicides_no.sum()

info=data[(data.country=="Albania") & (data.year==1987) & (data.sex=="female")]
s_n_fm1=info.suicides_no.sum()
# -----------------------------------------------------------------------------------------
info=data[(data.country=="Albania") & (data.year==1988) & (data.sex=="male")]
s_n_m2=info.suicides_no.sum()

info=data[(data.country=="Albania") & (data.year==1988) & (data.sex=="female")]
s_n_fm2=info.suicides_no.sum()
# -----------------------------------------------------------------------------------------
info=data[(data.country=="Albania") & (data.year==1989) & (data.sex=="male")]
s_n_m3=info.suicides_no.sum()

info=data[(data.country=="Albania") & (data.year==1989) & (data.sex=="female")]
s_n_fm3=info.suicides_no.sum()
# -----------------------------------------------------------------------------------------
info=data[(data.country=="Albania") & (data.year==1990) & (data.sex=="male")]
s_n_m4=info.suicides_no.sum()

info=data[(data.country=="Albania") & (data.year==1990) & (data.sex=="female")]
s_n_fm4=info.suicides_no.sum()
# -----------------------------------------------------------------------------------------
info=data[(data.country=="Albania") & (data.year==1991) & (data.sex=="male")]
s_n_m5=info.suicides_no.sum()

info=data[(data.country=="Albania") & (data.year==1991) & (data.sex=="female")]
s_n_fm5=info.suicides_no.sum()
# -----------------------------------------------------------------------------------------
info=data[(data.country=="Albania") & (data.year==1992) & (data.sex=="male")]
s_n_m6=info.suicides_no.sum()

info=data[(data.country=="Albania") & (data.year==1992) & (data.sex=="female")]
s_n_fm6=info.suicides_no.sum()
# -----------------------------------------------------------------------------------------# -----------------------------------------------------------------------------------------
info=data[(data.country=="Albania") & (data.year==1993) & (data.sex=="male")]
s_n_m7=info.suicides_no.sum()

info=data[(data.country=="Albania") & (data.year==1993) & (data.sex=="female")]
s_n_fm7=info.suicides_no.sum()
# -----------------------------------------------------------------------------------------

info=data[(data.country=="Albania") & (data.year==1994) & (data.sex=="male")]
s_n_m8=info.suicides_no.sum()

info=data[(data.country=="Albania") & (data.year==1994) & (data.sex=="female")]
s_n_fm8=info.suicides_no.sum()
# -----------------------------------------------------------------------------------------
info=data[(data.country=="Albania") & (data.year==1995) & (data.sex=="male")]
s_n_m9=info.suicides_no.sum()

info=data[(data.country=="Albania") & (data.year==1995) & (data.sex=="female")]
s_n_fm9=info.suicides_no.sum()
# -----------------------------------------------------------------------------------------
info=data[(data.country=="Albania") & (data.year==1996) & (data.sex=="male")]
s_n_m10=info.suicides_no.sum()

info=data[(data.country=="Albania") & (data.year==1996) & (data.sex=="female")]
s_n_fm10=info.suicides_no.sum()
# -----------------------------------------------------------------------------------------
info=data[(data.country=="Albania") & (data.year==1997) & (data.sex=="male")]
s_n_m11=info.suicides_no.sum()

info=data[(data.country=="Albania") & (data.year==1997) & (data.sex=="female")]
s_n_fm11=info.suicides_no.sum()
# -----------------------------------------------------------------------------------------

info=data[(data.country=="Albania") & (data.year==1998) & (data.sex=="male")]
s_n_m12=info.suicides_no.sum()

info=data[(data.country=="Albania") & (data.year==1998) & (data.sex=="female")]
s_n_fm12=info.suicides_no.sum()
# -----------------------------------------------------------------------------------------

info=data[(data.country=="Albania") & (data.year==1999) & (data.sex=="male")]
s_n_m13=info.suicides_no.sum()

info=data[(data.country=="Albania") & (data.year==1999) & (data.sex=="female")]
s_n_fm13=info.suicides_no.sum()
# -----------------------------------------------------------------------------------------
info=data[(data.country=="Albania") & (data.year==2000) & (data.sex=="male")]
s_n_m14=info.suicides_no.sum()

info=data[(data.country=="Albania") & (data.year==2000) & (data.sex=="female")]
s_n_fm14=info.suicides_no.sum()
# -----------------------------------------------------------------------------------------
info=data[(data.country=="Albania") & (data.year==2001) & (data.sex=="male")]
s_n_m15=info.suicides_no.sum()

info=data[(data.country=="Albania") & (data.year==2001) & (data.sex=="female")]
s_n_fm15=info.suicides_no.sum()
# -----------------------------------------------------------------------------------------
info=data[(data.country=="Albania") & (data.year==2002) & (data.sex=="male")]
s_n_m16=info.suicides_no.sum()

info=data[(data.country=="Albania") & (data.year==2002) & (data.sex=="female")]
s_n_fm16=info.suicides_no.sum()
# -----------------------------------------------------------------------------------------

info=data[(data.country=="Albania") & (data.year==2003) & (data.sex=="male")]
s_n_m17=info.suicides_no.sum()

info=data[(data.country=="Albania") & (data.year==2003) & (data.sex=="female")]
s_n_fm17=info.suicides_no.sum()
# -----------------------------------------------------------------------------------------

info=data[(data.country=="Albania") & (data.year==2004) & (data.sex=="male")]
s_n_m18=info.suicides_no.sum()

info=data[(data.country=="Albania") & (data.year==2004) & (data.sex=="female")]
s_n_fm18=info.suicides_no.sum()
# -----------------------------------------------------------------------------------------

info=data[(data.country=="Albania") & (data.year==2005) & (data.sex=="male")]
s_n_m19=info.suicides_no.sum()

info=data[(data.country=="Albania") & (data.year==2005) & (data.sex=="female")]
s_n_fm19=info.suicides_no.sum()
# -----------------------------------------------------------------------------------------
info=data[(data.country=="Albania") & (data.year==2006) & (data.sex=="male")]
s_n_m20=info.suicides_no.sum()

info=data[(data.country=="Albania") & (data.year==2006) & (data.sex=="female")]
s_n_fm20=info.suicides_no.sum()
# -----------------------------------------------------------------------------------------
info=data[(data.country=="Albania") & (data.year==2007) & (data.sex=="male")]
s_n_m21=info.suicides_no.sum()

info=data[(data.country=="Albania") & (data.year==2007) & (data.sex=="female")]
s_n_fm21=info.suicides_no.sum()
# -----------------------------------------------------------------------------------------

info=data[(data.country=="Albania") & (data.year==2008) & (data.sex=="male")]
s_n_m22=info.suicides_no.sum()

info=data[(data.country=="Albania") & (data.year==2008) & (data.sex=="female")]
s_n_fm22=info.suicides_no.sum()
# -----------------------------------------------------------------------------------------

info=data[(data.country=="Albania") & (data.year==2009) & (data.sex=="male")]
s_n_m23=info.suicides_no.sum()

info=data[(data.country=="Albania") & (data.year==2009) & (data.sex=="female")]
s_n_fm23=info.suicides_no.sum()
# -----------------------------------------------------------------------------------------
info=data[(data.country=="Albania") & (data.year==2010) & (data.sex=="male")]
s_n_m24=info.suicides_no.sum()

info=data[(data.country=="Albania") & (data.year==2010) & (data.sex=="female")]
s_n_fm24=info.suicides_no.sum()
# -----------------------------------------------------------------------------------------
info=data[(data.country=="Albania") & (data.year==2011) & (data.sex=="male")]
s_n_m25=info.suicides_no.sum()

info=data[(data.country=="Albania") & (data.year==2011) & (data.sex=="female")]
s_n_fm25=info.suicides_no.sum()
# -----------------------------------------------------------------------------------------
info=data[(data.country=="Albania") & (data.year==2012) & (data.sex=="male")]
s_n_m26=info.suicides_no.sum()

info=data[(data.country=="Albania") & (data.year==2012) & (data.sex=="female")]
s_n_fm26=info.suicides_no.sum()
# -----------------------------------------------------------------------------------------

info=data[(data.country=="Albania") & (data.year==2013) & (data.sex=="male")]
s_n_m27=info.suicides_no.sum()

info=data[(data.country=="Albania") & (data.year==2013) & (data.sex=="female")]
s_n_fm27=info.suicides_no.sum()
# -----------------------------------------------------------------------------------------

info=data[(data.country=="Albania") & (data.year==2014) & (data.sex=="male")]
s_n_m28=info.suicides_no.sum()

info=data[(data.country=="Albania") & (data.year==2014) & (data.sex=="female")]
s_n_fm28=info.suicides_no.sum()
# -----------------------------------------------------------------------------------------
info=data[(data.country=="Albania") & (data.year==2015) & (data.sex=="male")]
s_n_m29=info.suicides_no.sum()

info=data[(data.country=="Albania") & (data.year==2015) & (data.sex=="female")]
s_n_fm29=info.suicides_no.sum()
# -----------------------------------------------------------------------------------------
info=data[(data.country=="Albania") & (data.year==2016) & (data.sex=="male")]
s_n_m30=info.suicides_no.sum()

info=data[(data.country=="Albania") & (data.year==2016) & (data.sex=="female")]
s_n_fm30=info.suicides_no.sum()
# -----------------------------------------------------------------------------------------

# %%
no_of_suicides_m1=[s_n_m1,s_n_m2,s_n_m3,s_n_m4,s_n_m5,s_n_m6,s_n_m7,s_n_m8,s_n_m9,s_n_m10,s_n_m11,s_n_m12,s_n_m13,s_n_m14,s_n_m15,s_n_m16,s_n_m17,s_n_m18,s_n_m19,s_n_m20,s_n_m21,s_n_m22,s_n_m23,s_n_m24,s_n_m25,s_n_m26,s_n_m27,s_n_m28,s_n_m29,s_n_m30]
no_of_suicides_f1=[s_n_fm1,s_n_fm2,s_n_fm3,s_n_fm4,s_n_fm5,s_n_fm6,s_n_fm7,s_n_fm8,s_n_fm9,s_n_fm10,s_n_fm11,s_n_fm12,s_n_fm13,s_n_fm14,s_n_fm15,s_n_fm16,s_n_fm17,s_n_fm18,s_n_fm19,s_n_fm20,s_n_fm21,s_n_fm22,s_n_fm23,s_n_fm24,s_n_fm25,s_n_fm26,s_n_fm27,s_n_fm28,s_n_fm29,s_n_fm30]

# %% [markdown]
# # Overall male and female suicide in  Albania

# %%
years=[1987,1988,1989,1990,1991,1992,1993,1994,1995,1996,1997,1998,1999,2000,2001,2002,2003,2004,2005,2006,2007,2008,2009,2010,2011,2012,2013,2014,2015,2016]
plt.figure(figsize=(15,6))
plt.bar(years,no_of_suicides_m1,label="Male",color='skyblue')
plt.bar(years,no_of_suicides_f1,label="Female")
plt.title("Suicide Attempts 1987-2016 in Albania",fontsize=20)
plt.xlabel("Attempted Suicide years",fontsize=20)
plt.ylabel("Number of Suicide Attempted",fontsize=20)
style.use('ggplot')
plt.legend(fontsize=10)
plt.grid(color='white')

# %% [markdown]
# # Country,Year,ages
# - Argentina
# - 1987-2016
# - ages
#    - 15-24 years
#    - 35-54 years
#    - 75+ years
#    - 25-34 years
#    - 55-74 years
#    - 5-14 years
# - Male & Female

# %%
info=data[(data.country=="Argentina") & (data.year==1987) & (data.sex=="male")]
s_n_m1=info.suicides_no.sum()

info=data[(data.country=="Argentina") & (data.year==1987) & (data.sex=="female")]
s_n_fm1=info.suicides_no.sum()
# -----------------------------------------------------------------------------------------
info=data[(data.country=="Argentina") & (data.year==1988) & (data.sex=="male")]
s_n_m2=info.suicides_no.sum()

info=data[(data.country=="Argentina") & (data.year==1988) & (data.sex=="female")]
s_n_fm2=info.suicides_no.sum()
# -----------------------------------------------------------------------------------------
info=data[(data.country=="Argentina") & (data.year==1989) & (data.sex=="male")]
s_n_m3=info.suicides_no.sum()

info=data[(data.country=="Argentina") & (data.year==1989) & (data.sex=="female")]
s_n_fm3=info.suicides_no.sum()
# -----------------------------------------------------------------------------------------
info=data[(data.country=="Argentina") & (data.year==1990) & (data.sex=="male")]
s_n_m4=info.suicides_no.sum()

info=data[(data.country=="Argentina") & (data.year==1990) & (data.sex=="female")]
s_n_fm4=info.suicides_no.sum()
# -----------------------------------------------------------------------------------------
info=data[(data.country=="Argentina") & (data.year==1991) & (data.sex=="male")]
s_n_m5=info.suicides_no.sum()

info=data[(data.country=="Argentina") & (data.year==1991) & (data.sex=="female")]
s_n_fm5=info.suicides_no.sum()
# -----------------------------------------------------------------------------------------
info=data[(data.country=="Argentina") & (data.year==1992) & (data.sex=="male")]
s_n_m6=info.suicides_no.sum()

info=data[(data.country=="Argentina") & (data.year==1992) & (data.sex=="female")]
s_n_fm6=info.suicides_no.sum()
# -----------------------------------------------------------------------------------------# -----------------------------------------------------------------------------------------
info=data[(data.country=="Argentina") & (data.year==1993) & (data.sex=="male")]
s_n_m7=info.suicides_no.sum()

info=data[(data.country=="Argentina") & (data.year==1993) & (data.sex=="female")]
s_n_fm7=info.suicides_no.sum()
# -----------------------------------------------------------------------------------------

info=data[(data.country=="Argentina") & (data.year==1994) & (data.sex=="male")]
s_n_m8=info.suicides_no.sum()

info=data[(data.country=="Argentina") & (data.year==1994) & (data.sex=="female")]
s_n_fm8=info.suicides_no.sum()
# -----------------------------------------------------------------------------------------
info=data[(data.country=="Argentina") & (data.year==1995) & (data.sex=="male")]
s_n_m9=info.suicides_no.sum()

info=data[(data.country=="Argentina") & (data.year==1995) & (data.sex=="female")]
s_n_fm9=info.suicides_no.sum()
# -----------------------------------------------------------------------------------------
info=data[(data.country=="Argentina") & (data.year==1996) & (data.sex=="male")]
s_n_m10=info.suicides_no.sum()

info=data[(data.country=="Argentina") & (data.year==1996) & (data.sex=="female")]
s_n_fm10=info.suicides_no.sum()
# -----------------------------------------------------------------------------------------
info=data[(data.country=="Argentina") & (data.year==1997) & (data.sex=="male")]
s_n_m11=info.suicides_no.sum()

info=data[(data.country=="Argentina") & (data.year==1997) & (data.sex=="female")]
s_n_fm11=info.suicides_no.sum()
# -----------------------------------------------------------------------------------------

info=data[(data.country=="Argentina") & (data.year==1998) & (data.sex=="male")]
s_n_m12=info.suicides_no.sum()

info=data[(data.country=="Argentina") & (data.year==1998) & (data.sex=="female")]
s_n_fm12=info.suicides_no.sum()
# -----------------------------------------------------------------------------------------

info=data[(data.country=="Argentina") & (data.year==1999) & (data.sex=="male")]
s_n_m13=info.suicides_no.sum()

info=data[(data.country=="Argentina") & (data.year==1999) & (data.sex=="female")]
s_n_fm13=info.suicides_no.sum()
# -----------------------------------------------------------------------------------------
info=data[(data.country=="Argentina") & (data.year==2000) & (data.sex=="male")]
s_n_m14=info.suicides_no.sum()

info=data[(data.country=="Argentina") & (data.year==2000) & (data.sex=="female")]
s_n_fm14=info.suicides_no.sum()
# -----------------------------------------------------------------------------------------
info=data[(data.country=="Argentina") & (data.year==2001) & (data.sex=="male")]
s_n_m15=info.suicides_no.sum()

info=data[(data.country=="Argentina") & (data.year==2001) & (data.sex=="female")]
s_n_fm15=info.suicides_no.sum()
# -----------------------------------------------------------------------------------------
info=data[(data.country=="Argentina") & (data.year==2002) & (data.sex=="male")]
s_n_m16=info.suicides_no.sum()

info=data[(data.country=="Argentina") & (data.year==2002) & (data.sex=="female")]
s_n_fm16=info.suicides_no.sum()
# -----------------------------------------------------------------------------------------

info=data[(data.country=="Argentina") & (data.year==2003) & (data.sex=="male")]
s_n_m17=info.suicides_no.sum()
info=data[(data.country=="Argentina") & (data.year==2003) & (data.sex=="female")]
s_n_fm17=info.suicides_no.sum()
# -----------------------------------------------------------------------------------------

info=data[(data.country=="Argentina") & (data.year==2004) & (data.sex=="male")]
s_n_m18=info.suicides_no.sum()

info=data[(data.country=="Argentina") & (data.year==2004) & (data.sex=="female")]
s_n_fm18=info.suicides_no.sum()
# -----------------------------------------------------------------------------------------

info=data[(data.country=="Argentina") & (data.year==2005) & (data.sex=="male")]
s_n_m19=info.suicides_no.sum()

info=data[(data.country=="Argentina") & (data.year==2005) & (data.sex=="female")]
s_n_fm19=info.suicides_no.sum()
# -----------------------------------------------------------------------------------------
info=data[(data.country=="Argentina") & (data.year==2006) & (data.sex=="male")]
s_n_m20=info.suicides_no.sum()

info=data[(data.country=="Argentina") & (data.year==2006) & (data.sex=="female")]
s_n_fm20=info.suicides_no.sum()
# -----------------------------------------------------------------------------------------
info=data[(data.country=="Argentina") & (data.year==2007) & (data.sex=="male")]
s_n_m21=info.suicides_no.sum()

info=data[(data.country=="Argentina") & (data.year==2007) & (data.sex=="female")]
s_n_fm21=info.suicides_no.sum()
# -----------------------------------------------------------------------------------------

info=data[(data.country=="Argentina") & (data.year==2008) & (data.sex=="male")]
s_n_m22=info.suicides_no.sum()

info=data[(data.country=="Argentina") & (data.year==2008) & (data.sex=="female")]
s_n_fm22=info.suicides_no.sum()
# -----------------------------------------------------------------------------------------

info=data[(data.country=="Argentina") & (data.year==2009) & (data.sex=="male")]
s_n_m23=info.suicides_no.sum()

info=data[(data.country=="Argentina") & (data.year==2009) & (data.sex=="female")]
s_n_fm23=info.suicides_no.sum()
# -----------------------------------------------------------------------------------------
info=data[(data.country=="Argentina") & (data.year==2010) & (data.sex=="male")]
s_n_m24=info.suicides_no.sum()

info=data[(data.country=="Argentina") & (data.year==2010) & (data.sex=="female")]
s_n_fm24=info.suicides_no.sum()
# -----------------------------------------------------------------------------------------
info=data[(data.country=="Argentina") & (data.year==2011) & (data.sex=="male")]
s_n_m25=info.suicides_no.sum()

info=data[(data.country=="Argentina") & (data.year==2011) & (data.sex=="female")]
s_n_fm25=info.suicides_no.sum()
# -----------------------------------------------------------------------------------------
info=data[(data.country=="Argentina") & (data.year==2012) & (data.sex=="male")]
s_n_m26=info.suicides_no.sum()

info=data[(data.country=="Argentina") & (data.year==2012) & (data.sex=="female")]
s_n_fm26=info.suicides_no.sum()
# -----------------------------------------------------------------------------------------

info=data[(data.country=="Argentina") & (data.year==2013) & (data.sex=="male")]
s_n_m27=info.suicides_no.sum()

info=data[(data.country=="Argentina") & (data.year==2013) & (data.sex=="female")]
s_n_fm27=info.suicides_no.sum()
# -----------------------------------------------------------------------------------------

info=data[(data.country=="Argentina") & (data.year==2014) & (data.sex=="male")]
s_n_m28=info.suicides_no.sum()

info=data[(data.country=="Argentina") & (data.year==2014) & (data.sex=="female")]
s_n_fm28=info.suicides_no.sum()
# -----------------------------------------------------------------------------------------
info=data[(data.country=="Argentina") & (data.year==2015) & (data.sex=="male")]
s_n_m29=info.suicides_no.sum()

info=data[(data.country=="Argentina") & (data.year==2015) & (data.sex=="female")]
s_n_fm29=info.suicides_no.sum()
# -----------------------------------------------------------------------------------------
info=data[(data.country=="Argentina") & (data.year==2016) & (data.sex=="male")]
s_n_m30=info.suicides_no.sum()

info=data[(data.country=="Argentina") & (data.year==2016) & (data.sex=="female")]
s_n_fm30=info.suicides_no.sum()
# -----------------------------------------------------------------------------------------
no_of_suicides_m2=[s_n_m1,s_n_m2,s_n_m3,s_n_m4,s_n_m5,s_n_m6,s_n_m7,s_n_m8,s_n_m9,s_n_m10,s_n_m11,s_n_m12,s_n_m13,s_n_m14,s_n_m15,s_n_m16,s_n_m17,s_n_m18,s_n_m19,s_n_m20,s_n_m21,s_n_m22,s_n_m23,s_n_m24,s_n_m25,s_n_m26,s_n_m27,s_n_m28,s_n_m29,s_n_m30]
no_of_suicides_f2=[s_n_fm1,s_n_fm2,s_n_fm3,s_n_fm4,s_n_fm5,s_n_fm6,s_n_fm7,s_n_fm8,s_n_fm9,s_n_fm10,s_n_fm11,s_n_fm12,s_n_fm13,s_n_fm14,s_n_fm15,s_n_fm16,s_n_fm17,s_n_fm18,s_n_fm19,s_n_fm20,s_n_fm21,s_n_fm22,s_n_fm23,s_n_fm24,s_n_fm25,s_n_fm26,s_n_fm27,s_n_fm28,s_n_fm29,s_n_fm30]

# %% [markdown]
# # Overall male and female suicide in Argentina

# %%
years=[1987,1988,1989,1990,1991,1992,1993,1994,1995,1996,1997,1998,1999,2000,2001,2002,2003,2004,2005,2006,2007,2008,2009,2010,2011,2012,2013,2014,2015,2016]
plt.figure(figsize=(15,6))
plt.bar(years,no_of_suicides_m2,label="Male",color='skyblue')
plt.bar(years,no_of_suicides_f2,label="Female")
plt.title("Suicide Attempts 1987-2016 in Argentina",fontsize=20)
plt.xlabel("Attempted Suicide years",fontsize=20)
plt.ylabel("Number of Suicide Attempted",fontsize=20)
style.use('ggplot')
plt.legend()
plt.grid(color='white')

# %% [markdown]
# # Country,Year,ages
# - New Zealand
# - 1987-2016
# - ages
# - 15-24 years
# - 35-54 years
# - 75+ years
# - 25-34 years
# - 55-74 years
# - 5-14 years
# - Male & Female

# %%
info=data[(data.country=="New Zealand") & (data.year==1987) & (data.sex=="male")]
s_n_m1=info.suicides_no.sum()

info=data[(data.country=="New Zealand") & (data.year==1987) & (data.sex=="female")]
s_n_fm1=info.suicides_no.sum()
# -----------------------------------------------------------------------------------------
info=data[(data.country=="New Zealand") & (data.year==1988) & (data.sex=="male")]
s_n_m2=info.suicides_no.sum()

info=data[(data.country=="New Zealand") & (data.year==1988) & (data.sex=="female")]
s_n_fm2=info.suicides_no.sum()
# -----------------------------------------------------------------------------------------
info=data[(data.country=="New Zealand") & (data.year==1989) & (data.sex=="male")]
s_n_m3=info.suicides_no.sum()

info=data[(data.country=="New Zealand") & (data.year==1989) & (data.sex=="female")]
s_n_fm3=info.suicides_no.sum()
# -----------------------------------------------------------------------------------------
info=data[(data.country=="New Zealand") & (data.year==1990) & (data.sex=="male")]
s_n_m4=info.suicides_no.sum()

info=data[(data.country=="New Zealand") & (data.year==1990) & (data.sex=="female")]
s_n_fm4=info.suicides_no.sum()
# -----------------------------------------------------------------------------------------
info=data[(data.country=="New Zealand") & (data.year==1991) & (data.sex=="male")]
s_n_m5=info.suicides_no.sum()

info=data[(data.country=="New Zealand") & (data.year==1991) & (data.sex=="female")]
s_n_fm5=info.suicides_no.sum()
# -----------------------------------------------------------------------------------------
info=data[(data.country=="New Zealand") & (data.year==1992) & (data.sex=="male")]
s_n_m6=info.suicides_no.sum()

info=data[(data.country=="New Zealand") & (data.year==1992) & (data.sex=="female")]
s_n_fm6=info.suicides_no.sum()
# ----------------------------------------------------------------------------------------- # -----------------------------------------------------------------------------------------
info=data[(data.country=="New Zealand") & (data.year==1993) & (data.sex=="male")]
s_n_m7=info.suicides_no.sum()

info=data[(data.country=="New Zealand") & (data.year==1993) & (data.sex=="female")]
s_n_fm7=info.suicides_no.sum()
# -----------------------------------------------------------------------------------------

info=data[(data.country=="New Zealand") & (data.year==1994) & (data.sex=="male")]
s_n_m8=info.suicides_no.sum()

info=data[(data.country=="New Zealand") & (data.year==1994) & (data.sex=="female")]
s_n_fm8=info.suicides_no.sum()
# -----------------------------------------------------------------------------------------
info=data[(data.country=="New Zealand") & (data.year==1995) & (data.sex=="male")]
s_n_m9=info.suicides_no.sum()

info=data[(data.country=="New Zealand") & (data.year==1995) & (data.sex=="female")]
s_n_fm9=info.suicides_no.sum()
# -----------------------------------------------------------------------------------------
info=data[(data.country=="New Zealand") & (data.year==1996) & (data.sex=="male")]
s_n_m10=info.suicides_no.sum()

info=data[(data.country=="New Zealand") & (data.year==1996) & (data.sex=="female")]
s_n_fm10=info.suicides_no.sum()
# -----------------------------------------------------------------------------------------
info=data[(data.country=="New Zealand") & (data.year==1997) & (data.sex=="male")]
s_n_m11=info.suicides_no.sum()

info=data[(data.country=="NewZealand") & (data.year==1997) & (data.sex=="female")]
s_n_fm11=info.suicides_no.sum()
# -----------------------------------------------------------------------------------------

info=data[(data.country=="New Zealand") & (data.year==1998) & (data.sex=="male")]
s_n_m12=info.suicides_no.sum()

info=data[(data.country=="New Zealand") & (data.year==1998) & (data.sex=="female")]
s_n_fm12=info.suicides_no.sum()
# -----------------------------------------------------------------------------------------

info=data[(data.country=="New Zealand") & (data.year==1999) & (data.sex=="male")]
s_n_m13=info.suicides_no.sum()

info=data[(data.country=="New Zealand") & (data.year==1999) & (data.sex=="female")]
s_n_fm13=info.suicides_no.sum()
# -----------------------------------------------------------------------------------------
info=data[(data.country=="New Zealand") & (data.year==2000) & (data.sex=="male")]
s_n_m14=info.suicides_no.sum()

info=data[(data.country=="New Zealand") & (data.year==2000) & (data.sex=="female")]
s_n_fm14=info.suicides_no.sum()
# -----------------------------------------------------------------------------------------
info=data[(data.country=="New Zealand") & (data.year==2001) & (data.sex=="male")]
s_n_m15=info.suicides_no.sum()

info=data[(data.country=="New Zealand") & (data.year==2001) & (data.sex=="female")]
s_n_fm15=info.suicides_no.sum()
# -----------------------------------------------------------------------------------------
info=data[(data.country=="New Zealand") & (data.year==2002) & (data.sex=="male")]
s_n_m16=info.suicides_no.sum()

info=data[(data.country=="New Zealand") & (data.year==2002) & (data.sex=="female")]
s_n_fm16=info.suicides_no.sum()
# -----------------------------------------------------------------------------------------

info=data[(data.country=="New Zealand") & (data.year==2003) & (data.sex=="male")]
s_n_m17=info.suicides_no.sum()
info=data[(data.country=="New Zealand") & (data.year==2003) & (data.sex=="female")]
s_n_fm17=info.suicides_no.sum()
# -----------------------------------------------------------------------------------------

info=data[(data.country=="New Zealand") & (data.year==2004) & (data.sex=="male")]
s_n_m18=info.suicides_no.sum()

info=data[(data.country=="New Zealand") & (data.year==2004) & (data.sex=="female")]
s_n_fm18=info.suicides_no.sum()
# -----------------------------------------------------------------------------------------

info=data[(data.country=="New Zealand") & (data.year==2005) & (data.sex=="male")]
s_n_m19=info.suicides_no.sum()

info=data[(data.country=="New Zealand") & (data.year==2005) & (data.sex=="female")]
s_n_fm19=info.suicides_no.sum()
# -----------------------------------------------------------------------------------------
info=data[(data.country=="New Zealand") & (data.year==2006) & (data.sex=="male")]
s_n_m20=info.suicides_no.sum()

info=data[(data.country=="New Zealand") & (data.year==2006) & (data.sex=="female")]
s_n_fm20=info.suicides_no.sum()
# -----------------------------------------------------------------------------------------
info=data[(data.country=="New Zealand") & (data.year==2007) & (data.sex=="male")]
s_n_m21=info.suicides_no.sum()

info=data[(data.country=="New Zealand") & (data.year==2007) & (data.sex=="female")]
s_n_fm21=info.suicides_no.sum()
# -----------------------------------------------------------------------------------------

info=data[(data.country=="New Zealand") & (data.year==2008) & (data.sex=="male")]
s_n_m22=info.suicides_no.sum()

info=data[(data.country=="New Zealand") & (data.year==2008) & (data.sex=="female")]
s_n_fm22=info.suicides_no.sum()
# -----------------------------------------------------------------------------------------

info=data[(data.country=="New Zealand") & (data.year==2009) & (data.sex=="male")]
s_n_m23=info.suicides_no.sum()

info=data[(data.country=="New Zealand") & (data.year==2009) & (data.sex=="female")]
s_n_fm23=info.suicides_no.sum()
# -----------------------------------------------------------------------------------------
info=data[(data.country=="New Zealand") & (data.year==2010) & (data.sex=="male")]
s_n_m24=info.suicides_no.sum()

info=data[(data.country=="New Zealand") & (data.year==2010) & (data.sex=="female")]
s_n_fm24=info.suicides_no.sum()
# -----------------------------------------------------------------------------------------
info=data[(data.country=="New Zealand") & (data.year==2011) & (data.sex=="male")]
s_n_m25=info.suicides_no.sum()

info=data[(data.country=="New Zealand") & (data.year==2011) & (data.sex=="female")]
s_n_fm25=info.suicides_no.sum()
# -----------------------------------------------------------------------------------------
info=data[(data.country=="New Zealand") & (data.year==2012) & (data.sex=="male")]
s_n_m26=info.suicides_no.sum()

info=data[(data.country=="New Zealand") & (data.year==2012) & (data.sex=="female")]
s_n_fm26=info.suicides_no.sum()
# -----------------------------------------------------------------------------------------

info=data[(data.country=="New Zealand") & (data.year==2013) & (data.sex=="male")]
s_n_m27=info.suicides_no.sum()

info=data[(data.country=="New Zealand") & (data.year==2013) & (data.sex=="female")]
s_n_fm27=info.suicides_no.sum()
# -----------------------------------------------------------------------------------------

info=data[(data.country=="New Zealand") & (data.year==2014) & (data.sex=="male")]
s_n_m28=info.suicides_no.sum()

info=data[(data.country=="New Zealand") & (data.year==2014) & (data.sex=="female")]
s_n_fm28=info.suicides_no.sum()
# -----------------------------------------------------------------------------------------
info=data[(data.country=="New Zealand") & (data.year==2015) & (data.sex=="male")]
s_n_m29=info.suicides_no.sum()

info=data[(data.country=="New Zealand") & (data.year==2015) & (data.sex=="female")]
s_n_fm29=info.suicides_no.sum()
# -----------------------------------------------------------------------------------------
info=data[(data.country=="Newzealand") & (data.year==2016) & (data.sex=="male")]
s_n_m30=info.suicides_no.sum()

info=data[(data.country=="New Zealand") & (data.year==2016) & (data.sex=="female")]
s_n_fm30=info.suicides_no.sum()
# -----------------------------------------------------------------------------------------
no_of_suicides_m3=[s_n_m1,s_n_m2,s_n_m3,s_n_m4,s_n_m5,s_n_m6,s_n_m7,s_n_m8,s_n_m9,s_n_m10,s_n_m11,s_n_m12,s_n_m13,s_n_m14,s_n_m15,s_n_m16,s_n_m17,s_n_m18,s_n_m19,s_n_m20,s_n_m21,s_n_m22,s_n_m23,s_n_m24,s_n_m25,s_n_m26,s_n_m27,s_n_m28,s_n_m29,s_n_m30]
no_of_suicides_f3=[s_n_fm1,s_n_fm2,s_n_fm3,s_n_fm4,s_n_fm5,s_n_fm6,s_n_fm7,s_n_fm8,s_n_fm9,s_n_fm10,s_n_fm11,s_n_fm12,s_n_fm13,s_n_fm14,s_n_fm15,s_n_fm16,s_n_fm17,s_n_fm18,s_n_fm19,s_n_fm20,s_n_fm21,s_n_fm22,s_n_fm23,s_n_fm24,s_n_fm25,s_n_fm26,s_n_fm27,s_n_fm28,s_n_fm29,s_n_fm30]

# %% [markdown]
# # Overall male and female suicide in  New Zealand

# %%
years=[1987,1988,1989,1990,1991,1992,1993,1994,1995,1996,1997,1998,1999,2000,2001,2002,2003,2004,2005,2006,2007,2008,2009,2010,2011,2012,2013,2014,2015,2016]
plt.figure(figsize=(15,6))
plt.bar(years,no_of_suicides_m3,label="Male",color='skyblue')
plt.bar(years,no_of_suicides_f3,label="Female",color='lightcoral')
plt.title("Suicide Attempts 1987-2016 in New Zealand",fontsize=20)
plt.xlabel("Attempted Suicide years",fontsize=20)
plt.ylabel("Number of Suicide Attempted",fontsize=20)
style.use('ggplot')
plt.legend()
plt.grid(color='white')

# %% [markdown]
# # Country,Year,ages
# - Japan
# - 1987-2016
# - ages
# - 15-24 years
# - 35-54 years
# - 75+ years
# - 25-34 years
# - 55-74 years
# - 5-14 years
# - Male & Female

# %%
info=data[(data.country=="Japan") & (data.year==1987) & (data.sex=="male")]
s_n_m1=info.suicides_no.sum()

info=data[(data.country=="Japan") & (data.year==1987) & (data.sex=="female")]
s_n_fm1=info.suicides_no.sum()
# -----------------------------------------------------------------------------------------
info=data[(data.country=="Japan") & (data.year==1988) & (data.sex=="male")]
s_n_m2=info.suicides_no.sum()

info=data[(data.country=="Japan") & (data.year==1988) & (data.sex=="female")]
s_n_fm2=info.suicides_no.sum()
# -----------------------------------------------------------------------------------------
info=data[(data.country=="Japan") & (data.year==1989) & (data.sex=="male")]
s_n_m3=info.suicides_no.sum()

info=data[(data.country=="Japan") & (data.year==1989) & (data.sex=="female")]
s_n_fm3=info.suicides_no.sum()
# -----------------------------------------------------------------------------------------
info=data[(data.country=="Japan") & (data.year==1990) & (data.sex=="male")]
s_n_m4=info.suicides_no.sum()

info=data[(data.country=="Japan") & (data.year==1990) & (data.sex=="female")]
s_n_fm4=info.suicides_no.sum()
# -----------------------------------------------------------------------------------------
info=data[(data.country=="Japan") & (data.year==1991) & (data.sex=="male")]
s_n_m5=info.suicides_no.sum()

info=data[(data.country=="Japan") & (data.year==1991) & (data.sex=="female")]
s_n_fm5=info.suicides_no.sum()
# -----------------------------------------------------------------------------------------
info=data[(data.country=="Japan") & (data.year==1992) & (data.sex=="male")]
s_n_m6=info.suicides_no.sum()

info=data[(data.country=="Japan") & (data.year==1992) & (data.sex=="female")]
s_n_fm6=info.suicides_no.sum()
# -----------------------------------------------------------------------------------------# -----------------------------------------------------------------------------------------
info=data[(data.country=="Japan") & (data.year==1993) & (data.sex=="male")]
s_n_m7=info.suicides_no.sum()

info=data[(data.country=="Japan") & (data.year==1993) & (data.sex=="female")]
s_n_fm7=info.suicides_no.sum()
# -----------------------------------------------------------------------------------------

info=data[(data.country=="Japan") & (data.year==1994) & (data.sex=="male")]
s_n_m8=info.suicides_no.sum()

info=data[(data.country=="Japan") & (data.year==1994) & (data.sex=="female")]
s_n_fm8=info.suicides_no.sum()
# -----------------------------------------------------------------------------------------
info=data[(data.country=="Japan") & (data.year==1995) & (data.sex=="male")]
s_n_m9=info.suicides_no.sum()

info=data[(data.country=="Japan") & (data.year==1995) & (data.sex=="female")]
s_n_fm9=info.suicides_no.sum()
# -----------------------------------------------------------------------------------------
info=data[(data.country=="Japan") & (data.year==1996) & (data.sex=="male")]
s_n_m10=info.suicides_no.sum()

info=data[(data.country=="Japan") & (data.year==1996) & (data.sex=="female")]
s_n_fm10=info.suicides_no.sum()
# -----------------------------------------------------------------------------------------
info=data[(data.country=="Japan") & (data.year==1997) & (data.sex=="male")]
s_n_m11=info.suicides_no.sum()

info=data[(data.country=="Japan") & (data.year==1997) & (data.sex=="female")]
s_n_fm11=info.suicides_no.sum()
# -----------------------------------------------------------------------------------------

info=data[(data.country=="Japan") & (data.year==1998) & (data.sex=="male")]
s_n_m12=info.suicides_no.sum()

info=data[(data.country=="Japan") & (data.year==1998) & (data.sex=="female")]
s_n_fm12=info.suicides_no.sum()
# -----------------------------------------------------------------------------------------

info=data[(data.country=="Japan") & (data.year==1999) & (data.sex=="male")]
s_n_m13=info.suicides_no.sum()

info=data[(data.country=="Japan") & (data.year==1999) & (data.sex=="female")]
s_n_fm13=info.suicides_no.sum()
# -----------------------------------------------------------------------------------------
info=data[(data.country=="Japan") & (data.year==2000) & (data.sex=="male")]
s_n_m14=info.suicides_no.sum()

info=data[(data.country=="Japan") & (data.year==2000) & (data.sex=="female")]
s_n_fm14=info.suicides_no.sum()
# -----------------------------------------------------------------------------------------
info=data[(data.country=="Japan") & (data.year==2001) & (data.sex=="male")]
s_n_m15=info.suicides_no.sum()

info=data[(data.country=="Japan") & (data.year==2001) & (data.sex=="female")]
s_n_fm15=info.suicides_no.sum()
# -----------------------------------------------------------------------------------------
info=data[(data.country=="Japan") & (data.year==2002) & (data.sex=="male")]
s_n_m16=info.suicides_no.sum()

info=data[(data.country=="Japan") & (data.year==2002) & (data.sex=="female")]
s_n_fm16=info.suicides_no.sum()
# -----------------------------------------------------------------------------------------

info=data[(data.country=="Japan") & (data.year==2003) & (data.sex=="male")]
s_n_m17=info.suicides_no.sum()
info=data[(data.country=="Japan") & (data.year==2003) & (data.sex=="female")]
s_n_fm17=info.suicides_no.sum()
# -----------------------------------------------------------------------------------------

info=data[(data.country=="Japan") & (data.year==2004) & (data.sex=="male")]
s_n_m18=info.suicides_no.sum()

info=data[(data.country=="Japan") & (data.year==2004) & (data.sex=="female")]
s_n_fm18=info.suicides_no.sum()
# -----------------------------------------------------------------------------------------

info=data[(data.country=="Japan") & (data.year==2005) & (data.sex=="male")]
s_n_m19=info.suicides_no.sum()

info=data[(data.country=="Japan") & (data.year==2005) & (data.sex=="female")]
s_n_fm19=info.suicides_no.sum()
# -----------------------------------------------------------------------------------------
info=data[(data.country=="Japan") & (data.year==2006) & (data.sex=="male")]
s_n_m20=info.suicides_no.sum()

info=data[(data.country=="Japan") & (data.year==2006) & (data.sex=="female")]
s_n_fm20=info.suicides_no.sum()
# -----------------------------------------------------------------------------------------
info=data[(data.country=="Japan") & (data.year==2007) & (data.sex=="male")]
s_n_m21=info.suicides_no.sum()

info=data[(data.country=="Japan") & (data.year==2007) & (data.sex=="female")]
s_n_fm21=info.suicides_no.sum()
# -----------------------------------------------------------------------------------------

info=data[(data.country=="Japan") & (data.year==2008) & (data.sex=="male")]
s_n_m22=info.suicides_no.sum()

info=data[(data.country=="Japan") & (data.year==2008) & (data.sex=="female")]
s_n_fm22=info.suicides_no.sum()
# -----------------------------------------------------------------------------------------

info=data[(data.country=="Japan") & (data.year==2009) & (data.sex=="male")]
s_n_m23=info.suicides_no.sum()

info=data[(data.country=="Japan") & (data.year==2009) & (data.sex=="female")]
s_n_fm23=info.suicides_no.sum()
# -----------------------------------------------------------------------------------------
info=data[(data.country=="Japan") & (data.year==2010) & (data.sex=="male")]
s_n_m24=info.suicides_no.sum()

info=data[(data.country=="Japan") & (data.year==2010) & (data.sex=="female")]
s_n_fm24=info.suicides_no.sum()
# -----------------------------------------------------------------------------------------
info=data[(data.country=="Japan") & (data.year==2011) & (data.sex=="male")]
s_n_m25=info.suicides_no.sum()

info=data[(data.country=="Japan") & (data.year==2011) & (data.sex=="female")]
s_n_fm25=info.suicides_no.sum()
# -----------------------------------------------------------------------------------------
info=data[(data.country=="Japan") & (data.year==2012) & (data.sex=="male")]
s_n_m26=info.suicides_no.sum()

info=data[(data.country=="Japan") & (data.year==2012) & (data.sex=="female")]
s_n_fm26=info.suicides_no.sum()
# -----------------------------------------------------------------------------------------

info=data[(data.country=="Japan") & (data.year==2013) & (data.sex=="male")]
s_n_m27=info.suicides_no.sum()

info=data[(data.country=="Japan") & (data.year==2013) & (data.sex=="female")]
s_n_fm27=info.suicides_no.sum()
# -----------------------------------------------------------------------------------------

info=data[(data.country=="Japan") & (data.year==2014) & (data.sex=="male")]
s_n_m28=info.suicides_no.sum()

info=data[(data.country=="Japan") & (data.year==2014) & (data.sex=="female")]
s_n_fm28=info.suicides_no.sum()
# -----------------------------------------------------------------------------------------
info=data[(data.country=="Japan") & (data.year==2015) & (data.sex=="male")]
s_n_m29=info.suicides_no.sum()

info=data[(data.country=="Japan") & (data.year==2015) & (data.sex=="female")]
s_n_fm29=info.suicides_no.sum()
# -----------------------------------------------------------------------------------------
info=data[(data.country=="Japan") & (data.year==2016) & (data.sex=="male")]
s_n_m30=info.suicides_no.sum()

info=data[(data.country=="Japan") & (data.year==2016) & (data.sex=="female")]
s_n_fm30=info.suicides_no.sum()
# -----------------------------------------------------------------------------------------
no_of_suicides_m4=[s_n_m1,s_n_m2,s_n_m3,s_n_m4,s_n_m5,s_n_m6,s_n_m7,s_n_m8,s_n_m9,s_n_m10,s_n_m11,s_n_m12,s_n_m13,s_n_m14,s_n_m15,s_n_m16,s_n_m17,s_n_m18,s_n_m19,s_n_m20,s_n_m21,s_n_m22,s_n_m23,s_n_m24,s_n_m25,s_n_m26,s_n_m27,s_n_m28,s_n_m29,s_n_m30]
no_of_suicides_f4=[s_n_fm1,s_n_fm2,s_n_fm3,s_n_fm4,s_n_fm5,s_n_fm6,s_n_fm7,s_n_fm8,s_n_fm9,s_n_fm10,s_n_fm11,s_n_fm12,s_n_fm13,s_n_fm14,s_n_fm15,s_n_fm16,s_n_fm17,s_n_fm18,s_n_fm19,s_n_fm20,s_n_fm21,s_n_fm22,s_n_fm23,s_n_fm24,s_n_fm25,s_n_fm26,s_n_fm27,s_n_fm28,s_n_fm29,s_n_fm30]

# %% [markdown]
# # Overall male and female suicide in japan

# %%
years=[1987,1988,1989,1990,1991,1992,1993,1994,1995,1996,1997,1998,1999,2000,2001,2002,2003,2004,2005,2006,2007,2008,2009,2010,2011,2012,2013,2014,2015,2016]
plt.figure(figsize=(15,6))
plt.bar(years,no_of_suicides_m4,label="Male",color='#00bff3')
plt.bar(years,no_of_suicides_f4,label="Female",color='#0f4971')
plt.title("Suicide Attempts 1987-2016 in New japan",fontsize=20)
plt.xlabel("Attempted Suicide years",fontsize=20)
plt.ylabel("Number of Suicide Attempted",fontsize=20)
style.use('ggplot')
plt.legend()
plt.grid(color='white')

# %% [markdown]
# # Country,Year,ages
# - Azerbaijan
# - 1987-2016
# - ages
# - 15-24 years
# - 35-54 years
# - 75+ years
# - 25-34 years
# - 55-74 years
# - 5-14 years
# - Male & Female

# %%
info=data[(data.country=="Azerbaijan") & (data.year==1987) & (data.sex=="male")]
s_n_m1=info.suicides_no.sum()

info=data[(data.country=="Azerbaijan") & (data.year==1987) & (data.sex=="female")]
s_n_fm1=info.suicides_no.sum()
# -----------------------------------------------------------------------------------------
info=data[(data.country=="Azerbaijan") & (data.year==1988) & (data.sex=="male")]
s_n_m2=info.suicides_no.sum()

info=data[(data.country=="Azerbaijan") & (data.year==1988) & (data.sex=="female")]
s_n_fm2=info.suicides_no.sum()
# -----------------------------------------------------------------------------------------
info=data[(data.country=="Azerbaijan") & (data.year==1989) & (data.sex=="male")]
s_n_m3=info.suicides_no.sum()

info=data[(data.country=="Azerbaijan") & (data.year==1989) & (data.sex=="female")]
s_n_fm3=info.suicides_no.sum()
# -----------------------------------------------------------------------------------------
info=data[(data.country=="Azerbaijan") & (data.year==1990) & (data.sex=="male")]
s_n_m4=info.suicides_no.sum()

info=data[(data.country=="Azerbaijan") & (data.year==1990) & (data.sex=="female")]
s_n_fm4=info.suicides_no.sum()
# -----------------------------------------------------------------------------------------
info=data[(data.country=="Azerbaijan") & (data.year==1991) & (data.sex=="male")]
s_n_m5=info.suicides_no.sum()

info=data[(data.country=="Azerbaijan") & (data.year==1991) & (data.sex=="female")]
s_n_fm5=info.suicides_no.sum()
# -----------------------------------------------------------------------------------------
info=data[(data.country=="Azerbaijan") & (data.year==1992) & (data.sex=="male")]
s_n_m6=info.suicides_no.sum()

info=data[(data.country=="Azerbaijan") & (data.year==1992) & (data.sex=="female")]
s_n_fm6=info.suicides_no.sum()
# -----------------------------------------------------------------------------------------# -----------------------------------------------------------------------------------------
info=data[(data.country=="Azerbaijan") & (data.year==1993) & (data.sex=="male")]
s_n_m7=info.suicides_no.sum()

info=data[(data.country=="Azerbaijan") & (data.year==1993) & (data.sex=="female")]
s_n_fm7=info.suicides_no.sum()
# -----------------------------------------------------------------------------------------

info=data[(data.country=="Azerbaijan") & (data.year==1994) & (data.sex=="male")]
s_n_m8=info.suicides_no.sum()

info=data[(data.country=="Azerbaijan") & (data.year==1994) & (data.sex=="female")]
s_n_fm8=info.suicides_no.sum()
# -----------------------------------------------------------------------------------------
info=data[(data.country=="Azerbaijan") & (data.year==1995) & (data.sex=="male")]
s_n_m9=info.suicides_no.sum()

info=data[(data.country=="Azerbaijan") & (data.year==1995) & (data.sex=="female")]
s_n_fm9=info.suicides_no.sum()
# -----------------------------------------------------------------------------------------
info=data[(data.country=="Azerbaijan") & (data.year==1996) & (data.sex=="male")]
s_n_m10=info.suicides_no.sum()

info=data[(data.country=="Azerbaijan") & (data.year==1996) & (data.sex=="female")]
s_n_fm10=info.suicides_no.sum()
# -----------------------------------------------------------------------------------------
info=data[(data.country=="Azerbaijan") & (data.year==1997) & (data.sex=="male")]
s_n_m11=info.suicides_no.sum()

info=data[(data.country=="Azerbaijan") & (data.year==1997) & (data.sex=="female")]
s_n_fm11=info.suicides_no.sum()
# -----------------------------------------------------------------------------------------

info=data[(data.country=="Azerbaijan") & (data.year==1998) & (data.sex=="male")]
s_n_m12=info.suicides_no.sum()

info=data[(data.country=="Azerbaijan") & (data.year==1998) & (data.sex=="female")]
s_n_fm12=info.suicides_no.sum()
# -----------------------------------------------------------------------------------------

info=data[(data.country=="Azerbaijan") & (data.year==1999) & (data.sex=="male")]
s_n_m13=info.suicides_no.sum()

info=data[(data.country=="Azerbaijan") & (data.year==1999) & (data.sex=="female")]
s_n_fm13=info.suicides_no.sum()
# -----------------------------------------------------------------------------------------
info=data[(data.country=="Azerbaijan") & (data.year==2000) & (data.sex=="male")]
s_n_m14=info.suicides_no.sum()

info=data[(data.country=="Azerbaijan") & (data.year==2000) & (data.sex=="female")]
s_n_fm14=info.suicides_no.sum()
# -----------------------------------------------------------------------------------------
info=data[(data.country=="Azerbaijan") & (data.year==2001) & (data.sex=="male")]
s_n_m15=info.suicides_no.sum()

info=data[(data.country=="Azerbaijan") & (data.year==2001) & (data.sex=="female")]
s_n_fm15=info.suicides_no.sum()
# -----------------------------------------------------------------------------------------
info=data[(data.country=="Azerbaijan") & (data.year==2002) & (data.sex=="male")]
s_n_m16=info.suicides_no.sum()

info=data[(data.country=="Azerbaijan") & (data.year==2002) & (data.sex=="female")]
s_n_fm16=info.suicides_no.sum()
# -----------------------------------------------------------------------------------------

info=data[(data.country=="Azerbaijan") & (data.year==2003) & (data.sex=="male")]
s_n_m17=info.suicides_no.sum()
info=data[(data.country=="Azerbaijan") & (data.year==2003) & (data.sex=="female")]
s_n_fm17=info.suicides_no.sum()
# -----------------------------------------------------------------------------------------

info=data[(data.country=="Azerbaijan") & (data.year==2004) & (data.sex=="male")]
s_n_m18=info.suicides_no.sum()

info=data[(data.country=="Azerbaijan") & (data.year==2004) & (data.sex=="female")]
s_n_fm18=info.suicides_no.sum()
# -----------------------------------------------------------------------------------------

info=data[(data.country=="Azerbaijan") & (data.year==2005) & (data.sex=="male")]
s_n_m19=info.suicides_no.sum()

info=data[(data.country=="Azerbaijan") & (data.year==2005) & (data.sex=="female")]
s_n_fm19=info.suicides_no.sum()
# -----------------------------------------------------------------------------------------
info=data[(data.country=="Azerbaijan") & (data.year==2006) & (data.sex=="male")]
s_n_m20=info.suicides_no.sum()

info=data[(data.country=="Azerbaijan") & (data.year==2006) & (data.sex=="female")]
s_n_fm20=info.suicides_no.sum()
# -----------------------------------------------------------------------------------------
info=data[(data.country=="Azerbaijan") & (data.year==2007) & (data.sex=="male")]
s_n_m21=info.suicides_no.sum()

info=data[(data.country=="Azerbaijan") & (data.year==2007) & (data.sex=="female")]
s_n_fm21=info.suicides_no.sum()
# -----------------------------------------------------------------------------------------

info=data[(data.country=="Azerbaijan") & (data.year==2008) & (data.sex=="male")]
s_n_m22=info.suicides_no.sum()

info=data[(data.country=="Azerbaijan") & (data.year==2008) & (data.sex=="female")]
s_n_fm22=info.suicides_no.sum()
# -----------------------------------------------------------------------------------------

info=data[(data.country=="Azerbaijan") & (data.year==2009) & (data.sex=="male")]
s_n_m23=info.suicides_no.sum()

info=data[(data.country=="Azerbaijan") & (data.year==2009) & (data.sex=="female")]
s_n_fm23=info.suicides_no.sum()
# -----------------------------------------------------------------------------------------
info=data[(data.country=="Azerbaijan") & (data.year==2010) & (data.sex=="male")]
s_n_m24=info.suicides_no.sum()

info=data[(data.country=="Azerbaijan") & (data.year==2010) & (data.sex=="female")]
s_n_fm24=info.suicides_no.sum()
# -----------------------------------------------------------------------------------------
info=data[(data.country=="Azerbaijan") & (data.year==2011) & (data.sex=="male")]
s_n_m25=info.suicides_no.sum()

info=data[(data.country=="Azerbaijan") & (data.year==2011) & (data.sex=="female")]
s_n_fm25=info.suicides_no.sum()
# -----------------------------------------------------------------------------------------
info=data[(data.country=="Azerbaijan") & (data.year==2012) & (data.sex=="male")]
s_n_m26=info.suicides_no.sum()

info=data[(data.country=="Azerbaijan") & (data.year==2012) & (data.sex=="female")]
s_n_fm26=info.suicides_no.sum()
# -----------------------------------------------------------------------------------------

info=data[(data.country=="Azerbaijan") & (data.year==2013) & (data.sex=="male")]
s_n_m27=info.suicides_no.sum()

info=data[(data.country=="Azerbaijan") & (data.year==2013) & (data.sex=="female")]
s_n_fm27=info.suicides_no.sum()
# -----------------------------------------------------------------------------------------

info=data[(data.country=="Azerbaijan") & (data.year==2014) & (data.sex=="male")]
s_n_m28=info.suicides_no.sum()

info=data[(data.country=="Azerbaijan") & (data.year==2014) & (data.sex=="female")]
s_n_fm28=info.suicides_no.sum()
# -----------------------------------------------------------------------------------------
info=data[(data.country=="Azerbaijan") & (data.year==2015) & (data.sex=="male")]
s_n_m29=info.suicides_no.sum()

info=data[(data.country=="Azerbaijan") & (data.year==2015) & (data.sex=="female")]
s_n_fm29=info.suicides_no.sum()
# -----------------------------------------------------------------------------------------
info=data[(data.country=="Azerbaijan") & (data.year==2016) & (data.sex=="male")]
s_n_m30=info.suicides_no.sum()

info=data[(data.country=="Azerbaijan") & (data.year==2016) & (data.sex=="female")]
s_n_fm30=info.suicides_no.sum()
# -----------------------------------------------------------------------------------------
no_of_suicides_m5=[s_n_m1,s_n_m2,s_n_m3,s_n_m4,s_n_m5,s_n_m6,s_n_m7,s_n_m8,s_n_m9,s_n_m10,s_n_m11,s_n_m12,s_n_m13,s_n_m14,s_n_m15,s_n_m16,s_n_m17,s_n_m18,s_n_m19,s_n_m20,s_n_m21,s_n_m22,s_n_m23,s_n_m24,s_n_m25,s_n_m26,s_n_m27,s_n_m28,s_n_m29,s_n_m30]
no_of_suicides_f5=[s_n_fm1,s_n_fm2,s_n_fm3,s_n_fm4,s_n_fm5,s_n_fm6,s_n_fm7,s_n_fm8,s_n_fm9,s_n_fm10,s_n_fm11,s_n_fm12,s_n_fm13,s_n_fm14,s_n_fm15,s_n_fm16,s_n_fm17,s_n_fm18,s_n_fm19,s_n_fm20,s_n_fm21,s_n_fm22,s_n_fm23,s_n_fm24,s_n_fm25,s_n_fm26,s_n_fm27,s_n_fm28,s_n_fm29,s_n_fm30]

# %%
years=[1987,1988,1989,1990,1991,1992,1993,1994,1995,1996,1997,1998,1999,2000,2001,2002,2003,2004,2005,2006,2007,2008,2009,2010,2011,2012,2013,2014,2015,2016]
plt.figure(figsize=(15,6))
plt.bar(years,no_of_suicides_m5,label="Male",color='#ed7d31')
plt.bar(years,no_of_suicides_f5,label="Female",linewidth=3,color='#ffc000')
plt.title("Suicide Attempts 1987-2016 in New Azerbaijan",fontsize=20)
plt.xlabel("Attempted Suicide years",fontsize=20)
plt.ylabel("Number of Suicide Attempted",fontsize=20)
style.use('ggplot')
plt.legend()
plt.grid(color='white')

# %% [markdown]
# # Number of Suicides According age in Albania

# %%
plt.figure(figsize=(12,5))
dat1=data.groupby(['country','age']).get_group(("Albania",'5-14 years'))
age1=(dat1['suicides_no']).sum()

dat2=data.groupby(['country','age']).get_group(("Albania",'15-24 years'))
age2=(dat2['suicides_no']).sum()

dat3=data.groupby(['country','age']).get_group(("Albania",'25-34 years'))
age3=(dat3['suicides_no']).sum()

dat4=data.groupby(['country','age']).get_group(("Albania",'35-54 years'))
age4=(dat4['suicides_no']).sum()

dat5=data.groupby(['country','age']).get_group(("Albania",'55-74 years'))
age5=(dat5['suicides_no']).sum()

dat6=data.groupby(['country','age']).get_group(("Albania",'75+ years'))
age6=(dat6['suicides_no']).sum()

ages1=[age1,age2,age3,age4,age5,age6]
age=['5-14 years','15-24 years','25-34 years','35-54 years','55-74 years','75+ years']
plt.bar(age,ages1,color='#becee2')
plt.show()

# %% [markdown]
# # Number of Suicides According age in Argentina

# %%
plt.figure(figsize=(12,5))
dat7=data.groupby(['country','age']).get_group(("Argentina",'5-14 years'))
age7=(dat7['suicides_no']).sum()

dat8=data.groupby(['country','age']).get_group(("Argentina",'15-24 years'))
age8=(dat8['suicides_no']).sum()

data9=data.groupby(['country','age']).get_group(("Argentina",'25-34 years'))
age9=(data9['suicides_no']).sum()


dat10=data.groupby(['country','age']).get_group(("Argentina",'35-54 years'))
age10=(dat10['suicides_no']).sum()


dat11=data.groupby(['country','age']).get_group(("Argentina",'55-74 years'))
age11=(dat11['suicides_no']).sum()


dat12=data.groupby(['country','age']).get_group(("Argentina",'75+ years'))
age12=(dat12['suicides_no']).sum()


ages2=[age7,age8,age9,age10,age11,age12]
age=['5-14 years','15-24 years','25-34 years','35-54 years','55-74 years','75+ years']
plt.bar(age,ages2,color='#f8e7a3')
plt.show()

# %%
plt.figure(figsize=(12,5))
dat7=data.groupby(['country','age']).get_group(("Japan",'5-14 years'))
age7=(dat7['suicides_no']).sum()

dat8=data.groupby(['country','age']).get_group(("Japan",'15-24 years'))
age8=(dat8['suicides_no']).sum()

data9=data.groupby(['country','age']).get_group(("Japan",'25-34 years'))
age9=(data9['suicides_no']).sum()


dat10=data.groupby(['country','age']).get_group(("Japan",'35-54 years'))
age10=(dat10['suicides_no']).sum()


dat11=data.groupby(['country','age']).get_group(("Japan",'55-74 years'))
age11=(dat11['suicides_no']).sum()


dat12=data.groupby(['country','age']).get_group(("Japan",'75+ years'))
age12=(dat12['suicides_no']).sum()


ages2=[age7,age8,age9,age10,age11,age12]
age=['5-14 years','15-24 years','25-34 years','35-54 years','55-74 years','75+ years']
plt.bar(age,ages2,color='#e4a3a3')
plt.show()

# %%
plt.figure(figsize=(12,5))
dat7=data.groupby(['country','age']).get_group(("New Zealand",'5-14 years'))
age7=(dat7['suicides_no']).sum()

dat8=data.groupby(['country','age']).get_group(("New Zealand",'15-24 years'))
age8=(dat8['suicides_no']).sum()

data9=data.groupby(['country','age']).get_group(("New Zealand",'25-34 years'))
age9=(data9['suicides_no']).sum()


dat10=data.groupby(['country','age']).get_group(("New Zealand",'35-54 years'))
age10=(dat10['suicides_no']).sum()


dat11=data.groupby(['country','age']).get_group(("New Zealand",'55-74 years'))
age11=(dat11['suicides_no']).sum()


dat12=data.groupby(['country','age']).get_group(("New Zealand",'75+ years'))
age12=(dat12['suicides_no']).sum()


ages2=[age7,age8,age9,age10,age11,age12]
age=['5-14 years','15-24 years','25-34 years','35-54 years','55-74 years','75+ years']
plt.bar(age,ages2,color='#a3cea3')
plt.show()

# %%
plt.figure(figsize=(12,5))
dat7=data.groupby(['country','age']).get_group(("Azerbaijan",'5-14 years'))
age7=(dat7['suicides_no']).sum()

dat8=data.groupby(['country','age']).get_group(("Azerbaijan",'15-24 years'))
age8=(dat8['suicides_no']).sum()

data9=data.groupby(['country','age']).get_group(("Azerbaijan",'25-34 years'))
age9=(data9['suicides_no']).sum()


dat10=data.groupby(['country','age']).get_group(("Azerbaijan",'35-54 years'))
age10=(dat10['suicides_no']).sum()


dat11=data.groupby(['country','age']).get_group(("Azerbaijan",'55-74 years'))
age11=(dat11['suicides_no']).sum()


dat12=data.groupby(['country','age']).get_group(("Azerbaijan",'75+ years'))
age12=(dat12['suicides_no']).sum()


ages2=[age7,age8,age9,age10,age11,age12]
age=['5-14 years','15-24 years','25-34 years','35-54 years','55-74 years','75+ years']
plt.bar(age,ages2,color='#2ec09b')
plt.show()

# %% [markdown]
# # Male suicides ratio 1987-2016 in 5 countries

# %%
info=data[(data.country=="Albania") & (data.year) & (data.sex=="male")]
s_n_m1=info.suicides_no.sum()
info=data[(data.country=="japan") & (data.year) & (data.sex=="male")]
s_n_m2=info.suicides_no.sum()
info=data[(data.country=="Argentina") & (data.year) & (data.sex=="male")]
s_n_m3=info.suicides_no.sum()
info=data[(data.country=="New Zealand") & (data.year) & (data.sex=="male")]
s_n_m4=info.suicides_no.sum()
info=data[(data.country=="Azharbhaijan") & (data.year) & (data.sex=="male")]
s_n_m5=info.suicides_no.sum()

# %%
country=["Albania",'japan',"Argentina","Azerbaijan","New Zealand"]
nom=[s_n_m1,s_n_m2,s_n_m3,s_n_m4,s_n_m5]
color=['deepskyblue','black','R','orange','pink']
explode=[0.2,0.5,0,0.2,0.5]
wedgeprop={"linewidth":1,"width":2,"edgecolor":"k"}
textprops={"fontsize" : 12}
plt.pie(nom,labels=country,
        explode=explode,
        autopct="%0.2f%%",
        pctdistance=1.2,
        shadow=True,
        labeldistance=1.7,
        radius=1.5,
        
        textprops=textprops,
        colors=color,)
plt.legend()
plt.show()

# %% [markdown]
# ## Female suicides ratio 1987-2016 in 5 countries

# %%
info=data[(data.country=="Albania") & (data.year) & (data.sex=="female")]
s_n_fm1=info.suicides_no.sum()
info=data[(data.country=="japan") & (data.year) & (data.sex=="female")]
s_n_fm2=info.suicides_no.sum()
info=data[(data.country=="Argentina") & (data.year) & (data.sex=="female")]
s_n_fm3=info.suicides_no.sum()
info=data[(data.country=="New Zealand") & (data.year) & (data.sex=="female")]
s_n_fm4=info.suicides_no.sum()
info=data[(data.country=="Azharbhaijan") & (data.year) & (data.sex=="female")]
s_n_fm5=info.suicides_no.sum()

# %%
country=["Albania",'japan',"Argentina","Azerbaijan","New Zealand"]
nofm=[s_n_fm1,s_n_fm2,s_n_fm3,s_n_fm4,s_n_fm5]
color=['deepskyblue','black','R','orange','pink']
explode=[0.2,0.5,0,0.2,0.5]
wedgeprop={"linewidth":1,"width":2,"edgecolor":"k"}
textprops={"fontsize" : 12}
plt.pie(nofm,labels=country,
        explode=explode,
        autopct="%0.2f%%",
        pctdistance=1.2,
        shadow=True,
        labeldistance=1.7,
        radius=1.5,
#         wedgeprops=wedgeprop,
        textprops=textprops,
        colors=color,)
plt.legend()
plt.show()
